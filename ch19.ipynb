# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# [<img src="https://raw.githubusercontent.com/taehojo/taehojo.github.io/master/assets/images/linktocolab.png" align="left"/> ](https://colab.research.google.com/github/taehojo/deeplearning/blob/master/colab/ch19-colab.ipynb)

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### 실습: GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 예제 파일에서 data 폴더 아래에 이미지가 저장될 gan_images 폴더가 함께 제공됩니다.
# 만약 이미지가 저장될 폴더가 없다면 아래 코드의 주석을 해제해 gan_images 폴더를 만듭니다.
# import os
# if not os.path.exists("./data/gan_images"):
#    os.makedirs("./data/gan_images")

# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("./data/gan_images/gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7401  g_loss:0.5198
# epoch:1  d_loss:0.5509  g_loss:0.2983
# epoch:2  d_loss:0.5307  g_loss:0.1902
# epoch:3  d_loss:0.5398  g_loss:0.2080
# epoch:4  d_loss:0.4976  g_loss:0.3171
# epoch:5  d_loss:0.4622  g_loss:0.5292
# epoch:6  d_loss:0.4259  g_loss:0.7017
# epoch:7  d_loss:0.4176  g_loss:0.7292
# epoch:8  d_loss:0.5183  g_loss:0.7091
# epoch:9  d_loss:0.5054  g_loss:0.5339
# epoch:10  d_loss:0.6694  g_loss:0.4449
# epoch:11  d_loss:0.6787  g_loss:0.4405
# epoch:12  d_loss:0.7028  g_loss:0.5052
# epoch:13  d_loss:0.6043  g_loss:0.7150
# epoch:14  d_loss:0.5256  g_loss:0.7928
# epoch:15  d_loss:0.5405  g_loss:0.8351
# epoch:16  d_loss:0.5323  g_loss:0.8835
# epoch:17  d_loss:0.4601  g_loss:0.9627
# epoch:18  d_loss:0.4793  g_loss:0.9762
# epoch:19  d_loss:0.4418  g_loss:1.0115
# epoch:20  d_loss:0.4355  g_loss:1.0522
# epoch:21  d_loss:0.4243  g_loss:1.0881
# epoch:22  d_loss:0.4250  g_loss:1.2232
# epoch:23  d_loss:0.4457  g_loss:1.2535
# epoch:24  d_loss:0.4308  g_loss:1.3348
# epoch:25  d_loss:0.3747  g_loss:1.5463
# epoch:26  d_loss:0.3536  g_loss:1.5385
# epoch:27  d_loss:0.3446  g_loss:1.6239
# epoch:28  d_loss:0.3048  g_loss:1.8502
# epoch:29  d_loss:0.2539  g_loss:2.2467
# epoch:30  d_loss:0.2357  g_loss:2.5173
# epoch:31  d_loss:0.2297  g_loss:2.7032
# epoch:32  d_loss:0.1522  g_loss:3.1342
# epoch:33  d_loss:0.1871  g_loss:3.4833
# epoch:34  d_loss:0.1893  g_loss:3.5896
# epoch:35  d_loss:0.2042  g_loss:3.8091
# epoch:36  d_loss:0.2478  g_loss:3.5893
# epoch:37  d_loss:0.2736  g_loss:3.0740
# epoch:38  d_loss:0.3847  g_loss:2.9375
# epoch:39  d_loss:0.3435  g_loss:3.5283
# epoch:40  d_loss:0.3055  g_loss:3.0661
# epoch:41  d_loss:0.1631  g_loss:2.7676
# epoch:42  d_loss:0.0828  g_loss:2.7068
# epoch:43  d_loss:0.0801  g_loss:3.1850
# epoch:44  d_loss:0.0614  g_loss:4.1982
# epoch:45  d_loss:0.0683  g_loss:4.4724
# epoch:46  d_loss:0.1115  g_loss:3.5009
# epoch:47  d_loss:0.1543  g_loss:4.3226
# epoch:48  d_loss:0.2721  g_loss:3.3379
# epoch:49  d_loss:0.3157  g_loss:3.5204
# epoch:50  d_loss:0.4557  g_loss:3.1805
# epoch:51  d_loss:0.4977  g_loss:3.2889
# epoch:52  d_loss:0.6038  g_loss:3.0979
# epoch:53  d_loss:0.4476  g_loss:3.2906
# epoch:54  d_loss:0.3577  g_loss:3.8607
# epoch:55  d_loss:0.2372  g_loss:3.9570
# epoch:56  d_loss:0.1881  g_loss:4.4902
# epoch:57  d_loss:0.1094  g_loss:5.2935
# epoch:58  d_loss:0.1938  g_loss:5.1077
# epoch:59  d_loss:0.1227  g_loss:4.6961
# epoch:60  d_loss:0.0975  g_loss:4.8458
# epoch:61  d_loss:0.1496  g_loss:4.0397
# epoch:62  d_loss:0.1213  g_loss:3.7799
# epoch:63  d_loss:0.2108  g_loss:3.0824
# epoch:64  d_loss:0.3065  g_loss:2.6139
# epoch:65  d_loss:0.3217  g_loss:3.5353
# epoch:66  d_loss:0.4464  g_loss:2.5676
# epoch:67  d_loss:0.6033  g_loss:2.2397
# epoch:68  d_loss:0.4754  g_loss:2.2559
# epoch:69  d_loss:0.4445  g_loss:2.8461
# epoch:70  d_loss:0.4515  g_loss:2.6374
# epoch:71  d_loss:0.3998  g_loss:2.5747
# epoch:72  d_loss:0.1766  g_loss:3.2837
# epoch:73  d_loss:0.2425  g_loss:3.7961
# epoch:74  d_loss:0.2121  g_loss:4.5850
# epoch:75  d_loss:0.2118  g_loss:4.9151
# epoch:76  d_loss:0.2250  g_loss:5.0552
# epoch:77  d_loss:0.2070  g_loss:4.8270
# epoch:78  d_loss:0.2120  g_loss:4.4664
# epoch:79  d_loss:0.2348  g_loss:4.3598
# epoch:80  d_loss:0.3113  g_loss:3.6592
# epoch:81  d_loss:0.3571  g_loss:4.1911
# epoch:82  d_loss:0.3464  g_loss:4.4111
# epoch:83  d_loss:0.5548  g_loss:3.6337
# epoch:84  d_loss:0.5583  g_loss:3.2652
# epoch:85  d_loss:0.4411  g_loss:3.2380
# epoch:86  d_loss:0.3270  g_loss:3.4954
# epoch:87  d_loss:0.5362  g_loss:2.3781
# epoch:88  d_loss:0.3483  g_loss:2.0988
# epoch:89  d_loss:0.4971  g_loss:2.0652
# epoch:90  d_loss:0.3401  g_loss:2.2984
# epoch:91  d_loss:0.2631  g_loss:3.3051
# epoch:92  d_loss:0.3695  g_loss:2.9773
# epoch:93  d_loss:0.3906  g_loss:2.5192
# epoch:94  d_loss:0.3465  g_loss:2.2446
# epoch:95  d_loss:0.2615  g_loss:2.5979
# epoch:96  d_loss:0.2906  g_loss:2.6830
# epoch:97  d_loss:0.3098  g_loss:2.8375
# epoch:98  d_loss:0.2822  g_loss:2.5180
# epoch:99  d_loss:0.2549  g_loss:2.5770
# epoch:100  d_loss:0.2355  g_loss:2.9028
# epoch:101  d_loss:0.2148  g_loss:2.3400
# epoch:102  d_loss:0.2595  g_loss:2.5346
# epoch:103  d_loss:0.2974  g_loss:2.6410
# epoch:104  d_loss:0.2715  g_loss:2.7629
# epoch:105  d_loss:0.3443  g_loss:2.6937
# epoch:106  d_loss:0.2057  g_loss:2.7757
# epoch:107  d_loss:0.2824  g_loss:2.5962
# epoch:108  d_loss:0.3667  g_loss:2.5433
# epoch:109  d_loss:0.2556  g_loss:2.6836
# epoch:110  d_loss:0.2168  g_loss:3.3815
# epoch:111  d_loss:0.3002  g_loss:2.5184
# epoch:112  d_loss:0.2465  g_loss:2.5224
# epoch:113  d_loss:0.2690  g_loss:2.8184
# epoch:114  d_loss:0.2315  g_loss:2.9428
# epoch:115  d_loss:0.3369  g_loss:2.6293
# epoch:116  d_loss:0.2834  g_loss:3.3486
# epoch:117  d_loss:0.2989  g_loss:2.4838
# epoch:118  d_loss:0.3036  g_loss:2.1174
# epoch:119  d_loss:0.2621  g_loss:2.8739
# epoch:120  d_loss:0.2282  g_loss:3.0308
# epoch:121  d_loss:0.3051  g_loss:3.3865
# epoch:122  d_loss:0.2849  g_loss:2.6412
# epoch:123  d_loss:0.2312  g_loss:3.0832
# epoch:124  d_loss:0.2826  g_loss:2.7212
# epoch:125  d_loss:0.1593  g_loss:3.4790
# epoch:126  d_loss:0.1562  g_loss:3.3444
# epoch:127  d_loss:0.1538  g_loss:3.6665
# epoch:128  d_loss:0.1934  g_loss:3.6138
# epoch:129  d_loss:0.1339  g_loss:3.2439
# epoch:130  d_loss:0.1722  g_loss:3.0104
# epoch:131  d_loss:0.1860  g_loss:3.4219
# epoch:132  d_loss:0.1168  g_loss:4.4500
# epoch:133  d_loss:0.1437  g_loss:4.3376
# epoch:134  d_loss:0.1615  g_loss:3.9995
# epoch:135  d_loss:0.1603  g_loss:3.9448
# epoch:136  d_loss:0.1532  g_loss:3.1131
# epoch:137  d_loss:0.1603  g_loss:3.6958
# epoch:138  d_loss:0.1617  g_loss:3.8498
# epoch:139  d_loss:0.2101  g_loss:3.3985
# epoch:140  d_loss:0.1631  g_loss:3.8205
# epoch:141  d_loss:0.3427  g_loss:4.0480
# epoch:142  d_loss:0.2202  g_loss:3.3274
# epoch:143  d_loss:0.2018  g_loss:3.7631
# epoch:144  d_loss:0.2168  g_loss:3.8105
# epoch:145  d_loss:0.1938  g_loss:3.8511
# epoch:146  d_loss:0.2301  g_loss:2.6844
# epoch:147  d_loss:0.3008  g_loss:3.2982
# epoch:148  d_loss:0.2547  g_loss:3.7448
# epoch:149  d_loss:0.2880  g_loss:3.4076
# epoch:150  d_loss:0.2207  g_loss:2.7424
# epoch:151  d_loss:0.2185  g_loss:3.1144
# epoch:152  d_loss:0.2196  g_loss:2.9555
# epoch:153  d_loss:0.2813  g_loss:3.3756
# epoch:154  d_loss:0.2782  g_loss:3.3831
# epoch:155  d_loss:0.3590  g_loss:3.3264
# epoch:156  d_loss:0.2818  g_loss:3.4526
# epoch:157  d_loss:0.3106  g_loss:3.2288
# epoch:158  d_loss:0.3016  g_loss:3.6162
# epoch:159  d_loss:0.2567  g_loss:3.9369
# epoch:160  d_loss:0.2256  g_loss:3.7407
# epoch:161  d_loss:0.2546  g_loss:3.6221
# epoch:162  d_loss:0.3248  g_loss:4.0841
# epoch:163  d_loss:0.2537  g_loss:3.4491
# epoch:164  d_loss:0.2534  g_loss:3.8484
# epoch:165  d_loss:0.2302  g_loss:3.3934
# epoch:166  d_loss:0.1914  g_loss:3.9213
# epoch:167  d_loss:0.2698  g_loss:3.5913
# epoch:168  d_loss:0.1811  g_loss:3.8534
# epoch:169  d_loss:0.1650  g_loss:3.8959
# epoch:170  d_loss:0.1600  g_loss:3.6129
# epoch:171  d_loss:0.1909  g_loss:3.6806
# epoch:172  d_loss:0.1263  g_loss:3.6729
# epoch:173  d_loss:0.1343  g_loss:4.1884
# epoch:174  d_loss:0.1284  g_loss:4.1655
# epoch:175  d_loss:0.1438  g_loss:4.5126
# epoch:176  d_loss:0.1706  g_loss:4.6482
# epoch:177  d_loss:0.1124  g_loss:4.8449
# epoch:178  d_loss:0.1756  g_loss:3.5436
# epoch:179  d_loss:0.1838  g_loss:3.6535
# epoch:180  d_loss:0.1551  g_loss:3.9099
# epoch:181  d_loss:0.2013  g_loss:4.7401
# epoch:182  d_loss:0.1398  g_loss:4.5424
# epoch:183  d_loss:0.2503  g_loss:3.8943
# epoch:184  d_loss:0.2738  g_loss:3.5644
# epoch:185  d_loss:0.2410  g_loss:3.7215
# epoch:186  d_loss:0.1583  g_loss:3.3626
# epoch:187  d_loss:0.1569  g_loss:3.5850
# epoch:188  d_loss:0.1194  g_loss:3.9684
# epoch:189  d_loss:0.2035  g_loss:2.6315
# epoch:190  d_loss:0.2284  g_loss:2.9350
# epoch:191  d_loss:0.1121  g_loss:3.5214
# epoch:192  d_loss:0.1881  g_loss:3.4059
# epoch:193  d_loss:0.2177  g_loss:3.3421
# epoch:194  d_loss:0.1785  g_loss:3.2545
# epoch:195  d_loss:0.2634  g_loss:3.0224
# epoch:196  d_loss:0.2352  g_loss:3.8185
# epoch:197  d_loss:0.1953  g_loss:3.6886
# epoch:198  d_loss:0.1408  g_loss:4.0102
# epoch:199  d_loss:0.1813  g_loss:3.3367
# epoch:200  d_loss:0.1428  g_loss:3.1891
# epoch:201  d_loss:0.2234  g_loss:3.3896
# epoch:202  d_loss:0.2183  g_loss:4.2564
# epoch:203  d_loss:0.1911  g_loss:4.5059
# epoch:204  d_loss:0.2481  g_loss:3.4181
# epoch:205  d_loss:0.2134  g_loss:3.3679
# epoch:206  d_loss:0.2982  g_loss:3.5378
# epoch:207  d_loss:0.1212  g_loss:4.3079
# epoch:208  d_loss:0.1091  g_loss:4.1515
# epoch:209  d_loss:0.2020  g_loss:4.7836
# epoch:210  d_loss:0.1885  g_loss:4.0989
# epoch:211  d_loss:0.1095  g_loss:4.4965
# epoch:212  d_loss:0.1084  g_loss:4.0991
# epoch:213  d_loss:0.0819  g_loss:4.1472
# epoch:214  d_loss:0.1812  g_loss:4.8004
# epoch:215  d_loss:0.0819  g_loss:5.2912
# epoch:216  d_loss:0.1094  g_loss:5.0016
# epoch:217  d_loss:0.0942  g_loss:5.2142
# epoch:218  d_loss:0.1794  g_loss:4.8782
# epoch:219  d_loss:0.2047  g_loss:4.5255
# epoch:220  d_loss:0.0879  g_loss:4.3042
# epoch:221  d_loss:0.1422  g_loss:4.5287
# epoch:222  d_loss:0.1634  g_loss:4.8398
# epoch:223  d_loss:0.1342  g_loss:4.9988
# epoch:224  d_loss:0.2334  g_loss:5.0978
# epoch:225  d_loss:0.2280  g_loss:4.3486
# epoch:226  d_loss:0.1766  g_loss:4.7999
# epoch:227  d_loss:0.1409  g_loss:4.8431
# epoch:228  d_loss:0.1633  g_loss:4.2250
# epoch:229  d_loss:0.2261  g_loss:3.6770
# epoch:230  d_loss:0.2412  g_loss:4.1299
# epoch:231  d_loss:0.0793  g_loss:4.7234
# epoch:232  d_loss:0.1571  g_loss:4.0282
# epoch:233  d_loss:0.1533  g_loss:4.5470
# epoch:234  d_loss:0.1669  g_loss:3.6657
# epoch:235  d_loss:0.1566  g_loss:3.8212
# epoch:236  d_loss:0.2347  g_loss:4.0753
# epoch:237  d_loss:0.2280  g_loss:3.7896
# epoch:238  d_loss:0.2129  g_loss:3.5395
# epoch:239  d_loss:0.3242  g_loss:3.5474
# epoch:240  d_loss:0.1789  g_loss:4.0001
# epoch:241  d_loss:0.2029  g_loss:4.1654
# epoch:242  d_loss:0.1737  g_loss:3.6339
# epoch:243  d_loss:0.2079  g_loss:3.2302
# epoch:244  d_loss:0.1620  g_loss:3.4902
# epoch:245  d_loss:0.1247  g_loss:4.5724
# epoch:246  d_loss:0.1447  g_loss:4.8356
# epoch:247  d_loss:0.1735  g_loss:4.3863
# epoch:248  d_loss:0.1929  g_loss:4.1790
# epoch:249  d_loss:0.2097  g_loss:3.4544
# epoch:250  d_loss:0.1260  g_loss:4.3313
# epoch:251  d_loss:0.1164  g_loss:4.8566
# epoch:252  d_loss:0.2357  g_loss:4.4985
# epoch:253  d_loss:0.2149  g_loss:4.3230
# epoch:254  d_loss:0.1506  g_loss:3.6837
# epoch:255  d_loss:0.2516  g_loss:4.1051
# epoch:256  d_loss:0.1359  g_loss:4.5700
# epoch:257  d_loss:0.1542  g_loss:5.0436
# epoch:258  d_loss:0.2092  g_loss:3.5751
# epoch:259  d_loss:0.2263  g_loss:3.1252
# epoch:260  d_loss:0.2345  g_loss:3.0607
# epoch:261  d_loss:0.1686  g_loss:4.5626
# epoch:262  d_loss:0.2167  g_loss:4.9856
# epoch:263  d_loss:0.1850  g_loss:4.3576
# epoch:264  d_loss:0.2692  g_loss:3.8830
# epoch:265  d_loss:0.2260  g_loss:2.8685
# epoch:266  d_loss:0.4269  g_loss:3.6547
# epoch:267  d_loss:0.1109  g_loss:4.5466
# epoch:268  d_loss:0.2461  g_loss:5.0385
# epoch:269  d_loss:0.2282  g_loss:4.1522
# epoch:270  d_loss:0.1789  g_loss:3.1810
# epoch:271  d_loss:0.1272  g_loss:3.4184
# epoch:272  d_loss:0.2540  g_loss:3.5194
# epoch:273  d_loss:0.1937  g_loss:4.3057
# epoch:274  d_loss:0.1433  g_loss:3.8253
# epoch:275  d_loss:0.1537  g_loss:4.5919
# epoch:276  d_loss:0.2371  g_loss:3.4920
# epoch:277  d_loss:0.1385  g_loss:3.8393
# epoch:278  d_loss:0.2963  g_loss:4.1999
# epoch:279  d_loss:0.1823  g_loss:4.0325
# epoch:280  d_loss:0.1847  g_loss:2.8857
# epoch:281  d_loss:0.2362  g_loss:3.4830
# epoch:282  d_loss:0.2720  g_loss:3.2712
# epoch:283  d_loss:0.2182  g_loss:3.5491
# epoch:284  d_loss:0.2995  g_loss:3.5302
# epoch:285  d_loss:0.2672  g_loss:3.0456
# epoch:286  d_loss:0.1846  g_loss:3.7683
# epoch:287  d_loss:0.2087  g_loss:3.7840
# epoch:288  d_loss:0.2444  g_loss:4.5750
# epoch:289  d_loss:0.2124  g_loss:4.2666
# epoch:290  d_loss:0.2021  g_loss:3.9901
# epoch:291  d_loss:0.2370  g_loss:4.5275
# epoch:292  d_loss:0.2559  g_loss:4.3427
# epoch:293  d_loss:0.1745  g_loss:4.6865
# epoch:294  d_loss:0.2016  g_loss:3.9059
# epoch:295  d_loss:0.2540  g_loss:4.2938
# epoch:296  d_loss:0.1437  g_loss:3.8585
# epoch:297  d_loss:0.1656  g_loss:4.4709
# epoch:298  d_loss:0.1156  g_loss:4.3180
# epoch:299  d_loss:0.1645  g_loss:4.2405
# epoch:300  d_loss:0.1847  g_loss:4.2828
# epoch:301  d_loss:0.1237  g_loss:4.3856
# epoch:302  d_loss:0.1451  g_loss:4.3146
# epoch:303  d_loss:0.0752  g_loss:4.6317
# epoch:304  d_loss:0.1238  g_loss:4.4965
# epoch:305  d_loss:0.0640  g_loss:5.0275
# epoch:306  d_loss:0.1567  g_loss:3.7654
# epoch:307  d_loss:0.1610  g_loss:3.7761
# epoch:308  d_loss:0.1534  g_loss:4.1903
# epoch:309  d_loss:0.1117  g_loss:4.7408
# epoch:310  d_loss:0.2238  g_loss:3.7295
# epoch:311  d_loss:0.1675  g_loss:3.7949
# epoch:312  d_loss:0.1619  g_loss:4.0580
# epoch:313  d_loss:0.2288  g_loss:3.5312
# epoch:314  d_loss:0.1159  g_loss:4.3046
# epoch:315  d_loss:0.1694  g_loss:3.9646
# epoch:316  d_loss:0.1111  g_loss:4.0697
# epoch:317  d_loss:0.1419  g_loss:4.2601
# epoch:318  d_loss:0.1209  g_loss:5.1673
# epoch:319  d_loss:0.1520  g_loss:5.2492
# epoch:320  d_loss:0.1173  g_loss:4.5178
# epoch:321  d_loss:0.1368  g_loss:4.6130
# epoch:322  d_loss:0.1890  g_loss:4.0766
# epoch:323  d_loss:0.0827  g_loss:3.8998
# epoch:324  d_loss:0.1657  g_loss:4.6446
# epoch:325  d_loss:0.1153  g_loss:5.1427
# epoch:326  d_loss:0.2632  g_loss:3.5038
# epoch:327  d_loss:0.2453  g_loss:2.7101
# epoch:328  d_loss:0.2303  g_loss:3.2793
# epoch:329  d_loss:0.1768  g_loss:4.0926
# epoch:330  d_loss:0.1605  g_loss:4.7909
# epoch:331  d_loss:0.2538  g_loss:3.8355
# epoch:332  d_loss:0.1367  g_loss:2.8668
# epoch:333  d_loss:0.2251  g_loss:3.3649
# epoch:334  d_loss:0.0854  g_loss:3.9984
# epoch:335  d_loss:0.1011  g_loss:4.0557
# epoch:336  d_loss:0.2023  g_loss:4.2141
# epoch:337  d_loss:0.1572  g_loss:4.0817
# epoch:338  d_loss:0.0976  g_loss:3.8814
# epoch:339  d_loss:0.1607  g_loss:3.1196
# epoch:340  d_loss:0.1909  g_loss:2.8158
# epoch:341  d_loss:0.1312  g_loss:3.8784
# epoch:342  d_loss:0.0960  g_loss:4.1615
# epoch:343  d_loss:0.1621  g_loss:4.0907
# epoch:344  d_loss:0.1342  g_loss:3.1250
# epoch:345  d_loss:0.2060  g_loss:3.6281
# epoch:346  d_loss:0.1319  g_loss:3.8201
# epoch:347  d_loss:0.1151  g_loss:4.2244
# epoch:348  d_loss:0.1271  g_loss:3.9978
# epoch:349  d_loss:0.1125  g_loss:3.6593
# epoch:350  d_loss:0.2188  g_loss:3.7292
# epoch:351  d_loss:0.1104  g_loss:4.4648
# epoch:352  d_loss:0.1146  g_loss:4.3669
# epoch:353  d_loss:0.1366  g_loss:4.3034
# epoch:354  d_loss:0.1715  g_loss:4.2920
# epoch:355  d_loss:0.1010  g_loss:5.2952
# epoch:356  d_loss:0.1190  g_loss:4.9089
# epoch:357  d_loss:0.1103  g_loss:4.5195
# epoch:358  d_loss:0.1317  g_loss:4.6059
# epoch:359  d_loss:0.1628  g_loss:4.1300
# epoch:360  d_loss:0.2144  g_loss:4.0914
# epoch:361  d_loss:0.2988  g_loss:4.2259
# epoch:362  d_loss:0.1988  g_loss:4.8914
# epoch:363  d_loss:0.1992  g_loss:4.3471
# epoch:364  d_loss:0.2478  g_loss:3.3960
# epoch:365  d_loss:0.1815  g_loss:3.4635
# epoch:366  d_loss:0.2731  g_loss:3.2233
# epoch:367  d_loss:0.1266  g_loss:3.5036
# epoch:368  d_loss:0.1786  g_loss:3.8404
# epoch:369  d_loss:0.2069  g_loss:4.0523
# epoch:370  d_loss:0.1771  g_loss:3.8115
# epoch:371  d_loss:0.2315  g_loss:4.2015
# epoch:372  d_loss:0.2601  g_loss:3.5688
# epoch:373  d_loss:0.2327  g_loss:3.9113
# epoch:374  d_loss:0.1255  g_loss:4.0072
# epoch:375  d_loss:0.2054  g_loss:4.0686
# epoch:376  d_loss:0.2693  g_loss:3.2404
# epoch:377  d_loss:0.1526  g_loss:3.4432
# epoch:378  d_loss:0.0919  g_loss:4.0658
# epoch:379  d_loss:0.0736  g_loss:4.5208
# epoch:380  d_loss:0.0601  g_loss:5.3125
# epoch:381  d_loss:0.0576  g_loss:5.5738
# epoch:382  d_loss:0.1423  g_loss:4.4605
# epoch:383  d_loss:0.0526  g_loss:4.0621
# epoch:384  d_loss:0.1188  g_loss:4.0639
# epoch:385  d_loss:0.0539  g_loss:4.4591
# epoch:386  d_loss:0.1411  g_loss:4.4564
# epoch:387  d_loss:0.1462  g_loss:4.6098
# epoch:388  d_loss:0.1220  g_loss:4.5969
# epoch:389  d_loss:0.1987  g_loss:4.2664
# epoch:390  d_loss:0.1648  g_loss:4.1114
# epoch:391  d_loss:0.1117  g_loss:3.5035
# epoch:392  d_loss:0.1391  g_loss:4.0612
# epoch:393  d_loss:0.0764  g_loss:4.0967
# epoch:394  d_loss:0.1278  g_loss:5.1560
# epoch:395  d_loss:0.0955  g_loss:4.6849
# epoch:396  d_loss:0.1029  g_loss:4.1680
# epoch:397  d_loss:0.1019  g_loss:4.6582
# epoch:398  d_loss:0.0872  g_loss:5.0612
# epoch:399  d_loss:0.0926  g_loss:4.2003
# epoch:400  d_loss:0.0840  g_loss:4.4946
# epoch:401  d_loss:0.1018  g_loss:4.0494
# epoch:402  d_loss:0.0590  g_loss:4.3684
# epoch:403  d_loss:0.0943  g_loss:3.7330
# epoch:404  d_loss:0.1904  g_loss:3.6974
# epoch:405  d_loss:0.1537  g_loss:4.1419
# epoch:406  d_loss:0.0995  g_loss:4.5339
# epoch:407  d_loss:0.0965  g_loss:4.5844
# epoch:408  d_loss:0.1922  g_loss:4.3673
# epoch:409  d_loss:0.1415  g_loss:3.3478
# epoch:410  d_loss:0.1626  g_loss:3.5010
# epoch:411  d_loss:0.1532  g_loss:3.6029
# epoch:412  d_loss:0.1015  g_loss:4.3579
# epoch:413  d_loss:0.1282  g_loss:3.7886
# epoch:414  d_loss:0.1583  g_loss:3.9621
# epoch:415  d_loss:0.2123  g_loss:3.7231
# epoch:416  d_loss:0.1646  g_loss:3.7631
# epoch:417  d_loss:0.0748  g_loss:4.6112
# epoch:418  d_loss:0.1164  g_loss:3.9607
# epoch:419  d_loss:0.1448  g_loss:3.7953
# epoch:420  d_loss:0.0601  g_loss:5.9803
# epoch:421  d_loss:0.1302  g_loss:4.2801
# epoch:422  d_loss:0.1565  g_loss:3.2800
# epoch:423  d_loss:0.1236  g_loss:3.5643
# epoch:424  d_loss:0.0704  g_loss:4.0870
# epoch:425  d_loss:0.1590  g_loss:4.4667
# epoch:426  d_loss:0.0932  g_loss:4.7526
# epoch:427  d_loss:0.1103  g_loss:4.4187
# epoch:428  d_loss:0.1537  g_loss:3.7082
# epoch:429  d_loss:0.0975  g_loss:3.7256
# epoch:430  d_loss:0.1290  g_loss:3.8498
# epoch:431  d_loss:0.1753  g_loss:4.3886
# epoch:432  d_loss:0.1401  g_loss:4.9566
# epoch:433  d_loss:0.1985  g_loss:4.8949
# epoch:434  d_loss:0.2137  g_loss:3.4092
# epoch:435  d_loss:0.1624  g_loss:2.8080
# epoch:436  d_loss:0.1605  g_loss:3.3177
# epoch:437  d_loss:0.0661  g_loss:4.4370
# epoch:438  d_loss:0.1051  g_loss:5.1188
# epoch:439  d_loss:0.2119  g_loss:4.2706
# epoch:440  d_loss:0.1221  g_loss:3.4044
# epoch:441  d_loss:0.2198  g_loss:2.7113
# epoch:442  d_loss:0.0990  g_loss:4.6644
# epoch:443  d_loss:0.1340  g_loss:4.6789
# epoch:444  d_loss:0.1314  g_loss:4.1868
# epoch:445  d_loss:0.1519  g_loss:3.5864
# epoch:446  d_loss:0.1393  g_loss:2.2780
# epoch:447  d_loss:0.2200  g_loss:3.2203
# epoch:448  d_loss:0.1031  g_loss:4.5372
# epoch:449  d_loss:0.1623  g_loss:4.3449
# epoch:450  d_loss:0.2082  g_loss:4.4230
# epoch:451  d_loss:0.1116  g_loss:3.8707
# epoch:452  d_loss:0.1319  g_loss:2.8969
# epoch:453  d_loss:0.1965  g_loss:3.5115
# epoch:454  d_loss:0.1359  g_loss:3.7096
# epoch:455  d_loss:0.1043  g_loss:4.6061
# epoch:456  d_loss:0.1210  g_loss:4.5666
# epoch:457  d_loss:0.1140  g_loss:3.9843
# epoch:458  d_loss:0.1218  g_loss:3.6030
# epoch:459  d_loss:0.1035  g_loss:2.8605
# epoch:460  d_loss:0.1355  g_loss:2.8614
# epoch:461  d_loss:0.0930  g_loss:4.0269
# epoch:462  d_loss:0.1350  g_loss:3.0827
# epoch:463  d_loss:0.1240  g_loss:3.7061
# epoch:464  d_loss:0.1171  g_loss:3.2135
# epoch:465  d_loss:0.1779  g_loss:2.8206
# epoch:466  d_loss:0.1136  g_loss:3.2453
# epoch:467  d_loss:0.1582  g_loss:3.6355
# epoch:468  d_loss:0.0901  g_loss:4.5022
# epoch:469  d_loss:0.1310  g_loss:4.8757
# epoch:470  d_loss:0.1542  g_loss:3.6932
# epoch:471  d_loss:0.1626  g_loss:2.6226
# epoch:472  d_loss:0.2052  g_loss:3.2276
# epoch:473  d_loss:0.0986  g_loss:3.5238
# epoch:474  d_loss:0.0829  g_loss:4.2778
# epoch:475  d_loss:0.0574  g_loss:4.9831
# epoch:476  d_loss:0.1137  g_loss:4.2851
# epoch:477  d_loss:0.0975  g_loss:3.4390
# epoch:478  d_loss:0.1605  g_loss:3.0055
# epoch:479  d_loss:0.0944  g_loss:3.9279
# epoch:480  d_loss:0.1113  g_loss:4.1618
# epoch:481  d_loss:0.0681  g_loss:4.4069
# epoch:482  d_loss:0.1283  g_loss:5.3000
# epoch:483  d_loss:0.1592  g_loss:3.3381
# epoch:484  d_loss:0.0486  g_loss:3.9657
# epoch:485  d_loss:0.0705  g_loss:3.7532
# epoch:486  d_loss:0.1021  g_loss:3.0309
# epoch:487  d_loss:0.1726  g_loss:4.1411
# epoch:488  d_loss:0.0677  g_loss:4.8525
# epoch:489  d_loss:0.1619  g_loss:4.8940
# epoch:490  d_loss:0.1633  g_loss:4.0047
# epoch:491  d_loss:0.1430  g_loss:3.3842
# epoch:492  d_loss:0.1829  g_loss:2.9573
# epoch:493  d_loss:0.1154  g_loss:3.6508
# epoch:494  d_loss:0.0688  g_loss:3.8354
# epoch:495  d_loss:0.1419  g_loss:4.0915
# epoch:496  d_loss:0.0678  g_loss:3.8892
# epoch:497  d_loss:0.0797  g_loss:3.6846
# epoch:498  d_loss:0.1145  g_loss:3.1834
# epoch:499  d_loss:0.1244  g_loss:3.7241
# epoch:500  d_loss:0.0681  g_loss:4.4309
# epoch:501  d_loss:0.1184  g_loss:4.6888
# epoch:502  d_loss:0.1052  g_loss:3.7802
# epoch:503  d_loss:0.1384  g_loss:3.3382
# epoch:504  d_loss:0.1537  g_loss:3.9581
# epoch:505  d_loss:0.1041  g_loss:5.0220
# epoch:506  d_loss:0.1606  g_loss:4.7945
# epoch:507  d_loss:0.1659  g_loss:3.9650
# epoch:508  d_loss:0.1187  g_loss:2.9895
# epoch:509  d_loss:0.1364  g_loss:2.3101
# epoch:510  d_loss:0.2614  g_loss:3.2550
# epoch:511  d_loss:0.1213  g_loss:5.0663
# epoch:512  d_loss:0.2530  g_loss:4.9824
# epoch:513  d_loss:0.2060  g_loss:2.8150
# epoch:514  d_loss:0.2408  g_loss:2.1616
# epoch:515  d_loss:0.1352  g_loss:2.7330
# epoch:516  d_loss:0.1620  g_loss:3.5621
# epoch:517  d_loss:0.1434  g_loss:4.3817
# epoch:518  d_loss:0.2051  g_loss:3.7310
# epoch:519  d_loss:0.1531  g_loss:3.4995
# epoch:520  d_loss:0.1427  g_loss:3.0631
# epoch:521  d_loss:0.1094  g_loss:3.3885
# epoch:522  d_loss:0.1377  g_loss:4.0720
# epoch:523  d_loss:0.0986  g_loss:4.1638
# epoch:524  d_loss:0.1850  g_loss:3.6996
# epoch:525  d_loss:0.1015  g_loss:3.4492
# epoch:526  d_loss:0.1155  g_loss:3.5252
# epoch:527  d_loss:0.1051  g_loss:3.1660
# epoch:528  d_loss:0.0847  g_loss:4.4992
# epoch:529  d_loss:0.0849  g_loss:4.6766
# epoch:530  d_loss:0.1078  g_loss:4.3591
# epoch:531  d_loss:0.1123  g_loss:4.0247
# epoch:532  d_loss:0.2146  g_loss:3.1133
# epoch:533  d_loss:0.1514  g_loss:3.4329
# epoch:534  d_loss:0.0950  g_loss:3.9040
# epoch:535  d_loss:0.1182  g_loss:4.1806
# epoch:536  d_loss:0.0874  g_loss:4.2428
# epoch:537  d_loss:0.1140  g_loss:3.8266
# epoch:538  d_loss:0.0932  g_loss:3.7731
# epoch:539  d_loss:0.1220  g_loss:2.8196
# epoch:540  d_loss:0.1524  g_loss:2.9073
# epoch:541  d_loss:0.1489  g_loss:3.6061
# epoch:542  d_loss:0.1031  g_loss:3.8429
# epoch:543  d_loss:0.1261  g_loss:3.8541
# epoch:544  d_loss:0.1906  g_loss:3.4291
# epoch:545  d_loss:0.1186  g_loss:3.1783
# epoch:546  d_loss:0.1890  g_loss:3.1301
# epoch:547  d_loss:0.1414  g_loss:3.7681
# epoch:548  d_loss:0.1545  g_loss:2.9372
# epoch:549  d_loss:0.2011  g_loss:3.5965
# epoch:550  d_loss:0.1111  g_loss:3.7118
# epoch:551  d_loss:0.1559  g_loss:3.1020
# epoch:552  d_loss:0.0916  g_loss:3.3864
# epoch:553  d_loss:0.1185  g_loss:3.6364
# epoch:554  d_loss:0.0852  g_loss:3.3497
# epoch:555  d_loss:0.0986  g_loss:3.4957
# epoch:556  d_loss:0.0775  g_loss:3.8269
# epoch:557  d_loss:0.1499  g_loss:3.3634
# epoch:558  d_loss:0.1282  g_loss:4.1337
# epoch:559  d_loss:0.0699  g_loss:3.6204
# epoch:560  d_loss:0.0900  g_loss:3.8337
# epoch:561  d_loss:0.1417  g_loss:3.5069
# epoch:562  d_loss:0.0986  g_loss:3.7257
# epoch:563  d_loss:0.2481  g_loss:3.9218
# epoch:564  d_loss:0.1026  g_loss:4.0787
# epoch:565  d_loss:0.1705  g_loss:3.2683
# epoch:566  d_loss:0.1459  g_loss:3.7414
# epoch:567  d_loss:0.1617  g_loss:3.2658
# epoch:568  d_loss:0.1258  g_loss:3.5401
# epoch:569  d_loss:0.1294  g_loss:3.2372
# epoch:570  d_loss:0.1411  g_loss:3.7903
# epoch:571  d_loss:0.1468  g_loss:3.3165
# epoch:572  d_loss:0.1351  g_loss:3.6231
# epoch:573  d_loss:0.1151  g_loss:4.1755
# epoch:574  d_loss:0.1966  g_loss:3.3470
# epoch:575  d_loss:0.1517  g_loss:2.6921
# epoch:576  d_loss:0.2199  g_loss:2.9878
# epoch:577  d_loss:0.1945  g_loss:3.3133
# epoch:578  d_loss:0.2760  g_loss:3.0009
# epoch:579  d_loss:0.1423  g_loss:3.7294
# epoch:580  d_loss:0.1649  g_loss:3.4471
# epoch:581  d_loss:0.2809  g_loss:2.9409
# epoch:582  d_loss:0.2490  g_loss:2.7853
# epoch:583  d_loss:0.1852  g_loss:2.7564
# epoch:584  d_loss:0.2010  g_loss:3.3160
# epoch:585  d_loss:0.2593  g_loss:3.6489
# epoch:586  d_loss:0.1364  g_loss:4.5993
# epoch:587  d_loss:0.2551  g_loss:3.0946
# epoch:588  d_loss:0.1493  g_loss:2.0448
# epoch:589  d_loss:0.3224  g_loss:2.2831
# epoch:590  d_loss:0.1374  g_loss:3.7812
# epoch:591  d_loss:0.1131  g_loss:4.7899
# epoch:592  d_loss:0.1812  g_loss:4.0424
# epoch:593  d_loss:0.0886  g_loss:3.1147
# epoch:594  d_loss:0.1465  g_loss:3.0187
# epoch:595  d_loss:0.1144  g_loss:3.1894
# epoch:596  d_loss:0.0519  g_loss:4.3119
# epoch:597  d_loss:0.0782  g_loss:4.3581
# epoch:598  d_loss:0.1037  g_loss:3.7498
# epoch:599  d_loss:0.0842  g_loss:4.2065
# epoch:600  d_loss:0.0966  g_loss:3.5126
# epoch:601  d_loss:0.1129  g_loss:3.1134
# epoch:602  d_loss:0.1157  g_loss:3.1486
# epoch:603  d_loss:0.0887  g_loss:3.6499
# epoch:604  d_loss:0.0855  g_loss:4.4305
# epoch:605  d_loss:0.1473  g_loss:3.8462
# epoch:606  d_loss:0.0782  g_loss:3.5157
# epoch:607  d_loss:0.1821  g_loss:3.3558
# epoch:608  d_loss:0.1396  g_loss:4.4898
# epoch:609  d_loss:0.2105  g_loss:3.7819
# epoch:610  d_loss:0.1637  g_loss:3.7305
# epoch:611  d_loss:0.1919  g_loss:2.8925
# epoch:612  d_loss:0.1494  g_loss:3.2617
# epoch:613  d_loss:0.0701  g_loss:3.4284
# epoch:614  d_loss:0.0868  g_loss:4.0068
# epoch:615  d_loss:0.1040  g_loss:4.0189
# epoch:616  d_loss:0.1807  g_loss:2.9835
# epoch:617  d_loss:0.1302  g_loss:3.2575
# epoch:618  d_loss:0.1606  g_loss:2.9422
# epoch:619  d_loss:0.1663  g_loss:3.2302
# epoch:620  d_loss:0.0743  g_loss:4.7280
# epoch:621  d_loss:0.1758  g_loss:4.5576
# epoch:622  d_loss:0.1490  g_loss:3.2498
# epoch:623  d_loss:0.1587  g_loss:2.5762
# epoch:624  d_loss:0.0926  g_loss:3.5006
# epoch:625  d_loss:0.0844  g_loss:3.3997
# epoch:626  d_loss:0.0828  g_loss:3.4042
# epoch:627  d_loss:0.1079  g_loss:3.4264
# epoch:628  d_loss:0.1226  g_loss:3.8615
# epoch:629  d_loss:0.1072  g_loss:4.0374
# epoch:630  d_loss:0.1468  g_loss:4.2910
# epoch:631  d_loss:0.1289  g_loss:3.0794
# epoch:632  d_loss:0.1572  g_loss:2.7112
# epoch:633  d_loss:0.1643  g_loss:3.5019
# epoch:634  d_loss:0.1041  g_loss:4.2886
# epoch:635  d_loss:0.0683  g_loss:4.4323
# epoch:636  d_loss:0.1562  g_loss:3.8875
# epoch:637  d_loss:0.1158  g_loss:3.6251
# epoch:638  d_loss:0.1125  g_loss:3.4562
# epoch:639  d_loss:0.1723  g_loss:3.5956
# epoch:640  d_loss:0.1254  g_loss:3.7182
# epoch:641  d_loss:0.1059  g_loss:3.6334
# epoch:642  d_loss:0.0768  g_loss:3.8379
# epoch:643  d_loss:0.1341  g_loss:4.2929
# epoch:644  d_loss:0.0864  g_loss:3.4544
# epoch:645  d_loss:0.1328  g_loss:3.5261
# epoch:646  d_loss:0.0905  g_loss:3.1136
# epoch:647  d_loss:0.0759  g_loss:4.2032
# epoch:648  d_loss:0.1091  g_loss:3.3478
# epoch:649  d_loss:0.1187  g_loss:3.9399
# epoch:650  d_loss:0.0710  g_loss:3.1998
# epoch:651  d_loss:0.1400  g_loss:4.0153
# epoch:652  d_loss:0.1056  g_loss:4.2833
# epoch:653  d_loss:0.0508  g_loss:4.4998
# epoch:654  d_loss:0.1844  g_loss:3.9416
# epoch:655  d_loss:0.1088  g_loss:3.0812
# epoch:656  d_loss:0.1181  g_loss:3.5440
# epoch:657  d_loss:0.1216  g_loss:4.7870
# epoch:658  d_loss:0.0700  g_loss:4.4395
# epoch:659  d_loss:0.0697  g_loss:4.3234
# epoch:660  d_loss:0.1222  g_loss:3.9719
# epoch:661  d_loss:0.1522  g_loss:3.0446
# epoch:662  d_loss:0.1133  g_loss:4.1215
# epoch:663  d_loss:0.1274  g_loss:4.0285
# epoch:664  d_loss:0.0643  g_loss:4.1075
# epoch:665  d_loss:0.1343  g_loss:3.8530
# epoch:666  d_loss:0.1344  g_loss:3.0794
# epoch:667  d_loss:0.1457  g_loss:3.5118
# epoch:668  d_loss:0.0986  g_loss:4.9795
# epoch:669  d_loss:0.1150  g_loss:4.7703
# epoch:670  d_loss:0.0898  g_loss:3.5192
# epoch:671  d_loss:0.0890  g_loss:3.3323
# epoch:672  d_loss:0.0812  g_loss:3.9572
# epoch:673  d_loss:0.1152  g_loss:3.7617
# epoch:674  d_loss:0.0823  g_loss:4.2951
# epoch:675  d_loss:0.1083  g_loss:4.3296
# epoch:676  d_loss:0.1581  g_loss:3.7183
# epoch:677  d_loss:0.0711  g_loss:3.8727
# epoch:678  d_loss:0.0854  g_loss:4.3836
# epoch:679  d_loss:0.1435  g_loss:3.7452
# epoch:680  d_loss:0.0950  g_loss:3.5742
# epoch:681  d_loss:0.1368  g_loss:4.0548
# epoch:682  d_loss:0.0988  g_loss:4.3650
# epoch:683  d_loss:0.0927  g_loss:4.2493
# epoch:684  d_loss:0.1365  g_loss:3.8501
# epoch:685  d_loss:0.1881  g_loss:3.6310
# epoch:686  d_loss:0.0880  g_loss:4.1575
# epoch:687  d_loss:0.1061  g_loss:4.1330
# epoch:688  d_loss:0.0853  g_loss:3.7066
# epoch:689  d_loss:0.0900  g_loss:3.9682
# epoch:690  d_loss:0.1681  g_loss:3.4241
# epoch:691  d_loss:0.1556  g_loss:4.4566
# epoch:692  d_loss:0.0675  g_loss:4.6278
# epoch:693  d_loss:0.1184  g_loss:5.0079
# epoch:694  d_loss:0.1464  g_loss:4.4266
# epoch:695  d_loss:0.1296  g_loss:4.1683
# epoch:696  d_loss:0.1591  g_loss:3.7918
# epoch:697  d_loss:0.1841  g_loss:3.2125
# epoch:698  d_loss:0.1142  g_loss:4.0200
# epoch:699  d_loss:0.1307  g_loss:4.3547
# epoch:700  d_loss:0.0575  g_loss:4.6355
# epoch:701  d_loss:0.0648  g_loss:4.2697
# epoch:702  d_loss:0.1176  g_loss:3.4663
# epoch:703  d_loss:0.1505  g_loss:3.7572
# epoch:704  d_loss:0.1137  g_loss:4.4618
# epoch:705  d_loss:0.0793  g_loss:4.9613
# epoch:706  d_loss:0.1317  g_loss:4.5569
# epoch:707  d_loss:0.1842  g_loss:3.2021
# epoch:708  d_loss:0.1203  g_loss:3.3234
# epoch:709  d_loss:0.0830  g_loss:4.2631
# epoch:710  d_loss:0.0899  g_loss:4.8567
# epoch:711  d_loss:0.1129  g_loss:4.6540
# epoch:712  d_loss:0.1214  g_loss:4.0874
# epoch:713  d_loss:0.0784  g_loss:3.6379
# epoch:714  d_loss:0.0882  g_loss:4.6208
# epoch:715  d_loss:0.1585  g_loss:3.6278
# epoch:716  d_loss:0.1485  g_loss:3.2739
# epoch:717  d_loss:0.0939  g_loss:4.5594
# epoch:718  d_loss:0.1725  g_loss:3.9456
# epoch:719  d_loss:0.1167  g_loss:4.6198
# epoch:720  d_loss:0.0987  g_loss:4.6817
# epoch:721  d_loss:0.0821  g_loss:4.4310
# epoch:722  d_loss:0.1458  g_loss:3.6673
# epoch:723  d_loss:0.1016  g_loss:3.9344
# epoch:724  d_loss:0.1551  g_loss:4.6684
# epoch:725  d_loss:0.1527  g_loss:4.5612
# epoch:726  d_loss:0.1121  g_loss:4.2150
# epoch:727  d_loss:0.0718  g_loss:3.6585
# epoch:728  d_loss:0.0996  g_loss:3.7548
# epoch:729  d_loss:0.0693  g_loss:4.0021
# epoch:730  d_loss:0.2077  g_loss:4.9106
# epoch:731  d_loss:0.0654  g_loss:5.0968
# epoch:732  d_loss:0.1555  g_loss:4.5893
# epoch:733  d_loss:0.1054  g_loss:3.5519
# epoch:734  d_loss:0.1038  g_loss:3.9716
# epoch:735  d_loss:0.0562  g_loss:4.6999
# epoch:736  d_loss:0.0843  g_loss:3.9441
# epoch:737  d_loss:0.0672  g_loss:4.0208
# epoch:738  d_loss:0.0670  g_loss:4.4783
# epoch:739  d_loss:0.0707  g_loss:4.0326
# epoch:740  d_loss:0.1362  g_loss:3.6704
# epoch:741  d_loss:0.1137  g_loss:3.7052
# epoch:742  d_loss:0.1663  g_loss:4.1584
# epoch:743  d_loss:0.0737  g_loss:4.7236
# epoch:744  d_loss:0.1414  g_loss:3.8083
# epoch:745  d_loss:0.0796  g_loss:3.7024
# epoch:746  d_loss:0.1875  g_loss:3.9510
# epoch:747  d_loss:0.1058  g_loss:5.3978
# epoch:748  d_loss:0.1142  g_loss:4.8891
# epoch:749  d_loss:0.1220  g_loss:3.2062
# epoch:750  d_loss:0.0889  g_loss:3.7339
# epoch:751  d_loss:0.0557  g_loss:3.7666
# epoch:752  d_loss:0.0930  g_loss:3.8453
# epoch:753  d_loss:0.1485  g_loss:3.9373
# epoch:754  d_loss:0.1097  g_loss:4.7123
# epoch:755  d_loss:0.1226  g_loss:4.5921
# epoch:756  d_loss:0.0951  g_loss:4.6080
# epoch:757  d_loss:0.1698  g_loss:3.6426
# epoch:758  d_loss:0.0797  g_loss:3.8469
# epoch:759  d_loss:0.1064  g_loss:4.5423
# epoch:760  d_loss:0.0642  g_loss:5.0290
# epoch:761  d_loss:0.1181  g_loss:4.6755
# epoch:762  d_loss:0.0701  g_loss:4.4006
# epoch:763  d_loss:0.0605  g_loss:3.9647
# epoch:764  d_loss:0.1004  g_loss:4.1959
# epoch:765  d_loss:0.1036  g_loss:4.5894
# epoch:766  d_loss:0.1276  g_loss:5.7328
# epoch:767  d_loss:0.0608  g_loss:6.1154
# epoch:768  d_loss:0.1552  g_loss:5.1705
# epoch:769  d_loss:0.0969  g_loss:3.6435
# epoch:770  d_loss:0.0761  g_loss:4.0535
# epoch:771  d_loss:0.0943  g_loss:4.7084
# epoch:772  d_loss:0.0570  g_loss:5.4103
# epoch:773  d_loss:0.1803  g_loss:5.6314
# epoch:774  d_loss:0.0593  g_loss:4.5730
# epoch:775  d_loss:0.2179  g_loss:3.4747
# epoch:776  d_loss:0.0588  g_loss:4.4487
# epoch:777  d_loss:0.1032  g_loss:4.8868
# epoch:778  d_loss:0.1226  g_loss:4.3243
# epoch:779  d_loss:0.0954  g_loss:4.3462
# epoch:780  d_loss:0.1321  g_loss:5.1224
# epoch:781  d_loss:0.0660  g_loss:5.2428
# epoch:782  d_loss:0.0873  g_loss:4.3171
# epoch:783  d_loss:0.1040  g_loss:4.2371
# epoch:784  d_loss:0.1299  g_loss:4.1917
# epoch:785  d_loss:0.1047  g_loss:4.3446
# epoch:786  d_loss:0.1044  g_loss:5.4859
# epoch:787  d_loss:0.1118  g_loss:5.0916
# epoch:788  d_loss:0.1860  g_loss:4.4852
# epoch:789  d_loss:0.1643  g_loss:4.9370
# epoch:790  d_loss:0.1263  g_loss:4.5765
# epoch:791  d_loss:0.0743  g_loss:4.1289
# epoch:792  d_loss:0.1381  g_loss:4.2991
# epoch:793  d_loss:0.1386  g_loss:3.4354
# epoch:794  d_loss:0.0978  g_loss:4.7450
# epoch:795  d_loss:0.0894  g_loss:5.6692
# epoch:796  d_loss:0.1212  g_loss:5.2202
# epoch:797  d_loss:0.1130  g_loss:4.2561
# epoch:798  d_loss:0.1071  g_loss:4.5648
# epoch:799  d_loss:0.0841  g_loss:3.4027
# epoch:800  d_loss:0.1233  g_loss:3.8217
# epoch:801  d_loss:0.1441  g_loss:4.8420
# epoch:802  d_loss:0.0907  g_loss:5.5042
# epoch:803  d_loss:0.1339  g_loss:4.4735
# epoch:804  d_loss:0.1236  g_loss:4.2854
# epoch:805  d_loss:0.0897  g_loss:3.8871
# epoch:806  d_loss:0.0434  g_loss:4.5508
# epoch:807  d_loss:0.0539  g_loss:4.7091
# epoch:808  d_loss:0.0736  g_loss:4.6330
# epoch:809  d_loss:0.0671  g_loss:4.4719
# epoch:810  d_loss:0.1648  g_loss:4.8797
# epoch:811  d_loss:0.1304  g_loss:4.9288
# epoch:812  d_loss:0.1117  g_loss:4.4860
# epoch:813  d_loss:0.0923  g_loss:4.0404
# epoch:814  d_loss:0.1157  g_loss:4.0554
# epoch:815  d_loss:0.0610  g_loss:5.2063
# epoch:816  d_loss:0.0398  g_loss:6.1097
# epoch:817  d_loss:0.1771  g_loss:4.9766
# epoch:818  d_loss:0.0813  g_loss:4.6719
# epoch:819  d_loss:0.0385  g_loss:4.5909
# epoch:820  d_loss:0.0576  g_loss:4.3207
# epoch:821  d_loss:0.0532  g_loss:4.9310
# epoch:822  d_loss:0.0688  g_loss:4.9457
# epoch:823  d_loss:0.1789  g_loss:4.4274
# epoch:824  d_loss:0.1453  g_loss:4.5415
# epoch:825  d_loss:0.0486  g_loss:4.9710
# epoch:826  d_loss:0.0882  g_loss:4.3814
# epoch:827  d_loss:0.0946  g_loss:4.7836
# epoch:828  d_loss:0.0956  g_loss:4.8901
# epoch:829  d_loss:0.1496  g_loss:4.4798
# epoch:830  d_loss:0.0925  g_loss:3.8777
# epoch:831  d_loss:0.0768  g_loss:4.1946
# epoch:832  d_loss:0.1243  g_loss:4.7720
# epoch:833  d_loss:0.1071  g_loss:4.7062
# epoch:834  d_loss:0.0884  g_loss:5.7465
# epoch:835  d_loss:0.1023  g_loss:4.9351
# epoch:836  d_loss:0.2155  g_loss:3.7508
# epoch:837  d_loss:0.0883  g_loss:3.8107
# epoch:838  d_loss:0.1020  g_loss:4.2250
# epoch:839  d_loss:0.0835  g_loss:4.9499
# epoch:840  d_loss:0.0934  g_loss:5.0454
# epoch:841  d_loss:0.1201  g_loss:4.7178
# epoch:842  d_loss:0.1026  g_loss:4.4591
# epoch:843  d_loss:0.0640  g_loss:4.8649
# epoch:844  d_loss:0.0802  g_loss:5.3762
# epoch:845  d_loss:0.0761  g_loss:5.0707
# epoch:846  d_loss:0.1255  g_loss:4.5330
# epoch:847  d_loss:0.0728  g_loss:3.9836
# epoch:848  d_loss:0.0931  g_loss:4.7543
# epoch:849  d_loss:0.0990  g_loss:4.0870
# epoch:850  d_loss:0.0612  g_loss:5.4028
# epoch:851  d_loss:0.0464  g_loss:5.8174
# epoch:852  d_loss:0.1386  g_loss:4.3403
# epoch:853  d_loss:0.1039  g_loss:3.0743
# epoch:854  d_loss:0.1105  g_loss:3.8590
# epoch:855  d_loss:0.1049  g_loss:4.8059
# epoch:856  d_loss:0.0481  g_loss:6.4777
# epoch:857  d_loss:0.1435  g_loss:5.5428
# epoch:858  d_loss:0.1439  g_loss:5.0940
# epoch:859  d_loss:0.1443  g_loss:3.9550
# epoch:860  d_loss:0.0259  g_loss:4.5912
# epoch:861  d_loss:0.1283  g_loss:5.3371
# epoch:862  d_loss:0.0486  g_loss:5.7982
# epoch:863  d_loss:0.1397  g_loss:4.9763
# epoch:864  d_loss:0.0661  g_loss:5.0310
# epoch:865  d_loss:0.0740  g_loss:4.4342
# epoch:866  d_loss:0.0612  g_loss:4.5161
# epoch:867  d_loss:0.0458  g_loss:5.4943
# epoch:868  d_loss:0.1014  g_loss:5.2441
# epoch:869  d_loss:0.0803  g_loss:5.3758
# epoch:870  d_loss:0.0985  g_loss:5.5226
# epoch:871  d_loss:0.0748  g_loss:4.6887
# epoch:872  d_loss:0.0599  g_loss:5.8683
# epoch:873  d_loss:0.0750  g_loss:5.4297
# epoch:874  d_loss:0.0592  g_loss:5.3706
# epoch:875  d_loss:0.0899  g_loss:4.5805
# epoch:876  d_loss:0.1213  g_loss:4.3000
# epoch:877  d_loss:0.0629  g_loss:4.5065
# epoch:878  d_loss:0.0728  g_loss:5.1817
# epoch:879  d_loss:0.0934  g_loss:4.2629
# epoch:880  d_loss:0.0562  g_loss:4.7870
# epoch:881  d_loss:0.0486  g_loss:5.2992
# epoch:882  d_loss:0.0453  g_loss:4.8637
# epoch:883  d_loss:0.1281  g_loss:5.1729
# epoch:884  d_loss:0.0558  g_loss:4.6955
# epoch:885  d_loss:0.0996  g_loss:5.0500
# epoch:886  d_loss:0.0952  g_loss:4.7855
# epoch:887  d_loss:0.0848  g_loss:5.3299
# epoch:888  d_loss:0.1187  g_loss:4.6278
# epoch:889  d_loss:0.0937  g_loss:4.4269
# epoch:890  d_loss:0.0575  g_loss:5.4947
# epoch:891  d_loss:0.1193  g_loss:4.9585
# epoch:892  d_loss:0.1268  g_loss:3.9076
# epoch:893  d_loss:0.1302  g_loss:5.5654
# epoch:894  d_loss:0.1236  g_loss:5.9785
# epoch:895  d_loss:0.1001  g_loss:6.3071
# epoch:896  d_loss:0.0803  g_loss:6.3059
# epoch:897  d_loss:0.1574  g_loss:4.1441
# epoch:898  d_loss:0.0699  g_loss:3.6211
# epoch:899  d_loss:0.1889  g_loss:3.7473
# epoch:900  d_loss:0.0866  g_loss:5.3145
# epoch:901  d_loss:0.0362  g_loss:6.2015
# epoch:902  d_loss:0.0921  g_loss:5.6557
# epoch:903  d_loss:0.1936  g_loss:3.0698
# epoch:904  d_loss:0.2081  g_loss:3.8716
# epoch:905  d_loss:0.1177  g_loss:4.3625
# epoch:906  d_loss:0.0402  g_loss:6.4787
# epoch:907  d_loss:0.1613  g_loss:6.7744
# epoch:908  d_loss:0.0913  g_loss:4.8187
# epoch:909  d_loss:0.1267  g_loss:3.8733
# epoch:910  d_loss:0.0342  g_loss:4.6707
# epoch:911  d_loss:0.0641  g_loss:5.3663
# epoch:912  d_loss:0.0584  g_loss:5.8590
# epoch:913  d_loss:0.0627  g_loss:5.2957
# epoch:914  d_loss:0.0792  g_loss:3.8920
# epoch:915  d_loss:0.0960  g_loss:4.3213
# epoch:916  d_loss:0.0857  g_loss:5.2248
# epoch:917  d_loss:0.0895  g_loss:5.7786
# epoch:918  d_loss:0.1467  g_loss:4.6768
# epoch:919  d_loss:0.1183  g_loss:5.4774
# epoch:920  d_loss:0.0608  g_loss:5.0021
# epoch:921  d_loss:0.0469  g_loss:4.5814
# epoch:922  d_loss:0.1793  g_loss:4.8809
# epoch:923  d_loss:0.0527  g_loss:5.6354
# epoch:924  d_loss:0.0233  g_loss:6.0867
# epoch:925  d_loss:0.0751  g_loss:5.4079
# epoch:926  d_loss:0.0544  g_loss:5.4534
# epoch:927  d_loss:0.1033  g_loss:4.1271
# epoch:928  d_loss:0.1570  g_loss:4.2229
# epoch:929  d_loss:0.0768  g_loss:4.5045
# epoch:930  d_loss:0.0486  g_loss:4.8465
# epoch:931  d_loss:0.0953  g_loss:5.1470
# epoch:932  d_loss:0.1652  g_loss:3.9266
# epoch:933  d_loss:0.0858  g_loss:4.6386
# epoch:934  d_loss:0.0352  g_loss:6.3411
# epoch:935  d_loss:0.0936  g_loss:5.7251
# epoch:936  d_loss:0.0744  g_loss:5.0097
# epoch:937  d_loss:0.0468  g_loss:4.1481
# epoch:938  d_loss:0.0731  g_loss:4.3168
# epoch:939  d_loss:0.0378  g_loss:5.3771
# epoch:940  d_loss:0.0441  g_loss:6.1219
# epoch:941  d_loss:0.0486  g_loss:6.8814
# epoch:942  d_loss:0.0782  g_loss:5.1305
# epoch:943  d_loss:0.0772  g_loss:4.2745
# epoch:944  d_loss:0.0852  g_loss:4.6355
# epoch:945  d_loss:0.0279  g_loss:5.0859
# epoch:946  d_loss:0.0357  g_loss:6.7585
# epoch:947  d_loss:0.0555  g_loss:6.6230
# epoch:948  d_loss:0.0669  g_loss:5.5008
# epoch:949  d_loss:0.1363  g_loss:4.8742
# epoch:950  d_loss:0.0632  g_loss:5.3388
# epoch:951  d_loss:0.0429  g_loss:6.1532
# epoch:952  d_loss:0.1241  g_loss:5.8430
# epoch:953  d_loss:0.0787  g_loss:6.2302
# epoch:954  d_loss:0.1049  g_loss:5.5063
# epoch:955  d_loss:0.1304  g_loss:5.1990
# epoch:956  d_loss:0.0830  g_loss:5.3135
# epoch:957  d_loss:0.1790  g_loss:4.7788
# epoch:958  d_loss:0.0804  g_loss:4.9983
# epoch:959  d_loss:0.1195  g_loss:4.9836
# epoch:960  d_loss:0.0767  g_loss:4.4535
# epoch:961  d_loss:0.0464  g_loss:4.6148
# epoch:962  d_loss:0.0360  g_loss:4.4202
# epoch:963  d_loss:0.0454  g_loss:4.4037
# epoch:964  d_loss:0.1693  g_loss:4.8947
# epoch:965  d_loss:0.0616  g_loss:5.3675
# epoch:966  d_loss:0.1385  g_loss:6.3369
# epoch:967  d_loss:0.0560  g_loss:5.5699
# epoch:968  d_loss:0.1249  g_loss:5.0012
# epoch:969  d_loss:0.1040  g_loss:4.5122
# epoch:970  d_loss:0.1213  g_loss:4.3170
# epoch:971  d_loss:0.0680  g_loss:6.3699
# epoch:972  d_loss:0.0472  g_loss:7.6926
# epoch:973  d_loss:0.1008  g_loss:6.0791
# epoch:974  d_loss:0.0566  g_loss:6.0376
# epoch:975  d_loss:0.0681  g_loss:4.8642
# epoch:976  d_loss:0.0470  g_loss:4.6755
# epoch:977  d_loss:0.0729  g_loss:5.4918
# epoch:978  d_loss:0.0241  g_loss:6.3564
# epoch:979  d_loss:0.0866  g_loss:5.0871
# epoch:980  d_loss:0.0810  g_loss:5.0561
# epoch:981  d_loss:0.0402  g_loss:4.7657
# epoch:982  d_loss:0.1446  g_loss:5.1289
# epoch:983  d_loss:0.0616  g_loss:5.8287
# epoch:984  d_loss:0.0775  g_loss:5.1325
# epoch:985  d_loss:0.0797  g_loss:4.6534
# epoch:986  d_loss:0.0598  g_loss:4.4349
# epoch:987  d_loss:0.0506  g_loss:4.9670
# epoch:988  d_loss:0.0736  g_loss:5.6307
# epoch:989  d_loss:0.0544  g_loss:5.8298
# epoch:990  d_loss:0.0427  g_loss:5.2821
# epoch:991  d_loss:0.0438  g_loss:5.3069
# epoch:992  d_loss:0.0468  g_loss:4.8802
# epoch:993  d_loss:0.0605  g_loss:5.3339
# epoch:994  d_loss:0.0795  g_loss:4.0930
# epoch:995  d_loss:0.0360  g_loss:5.0222
# epoch:996  d_loss:0.0402  g_loss:5.8475
# epoch:997  d_loss:0.0757  g_loss:6.0141
# epoch:998  d_loss:0.1338  g_loss:6.3621
# epoch:999  d_loss:0.0524  g_loss:5.8853
# epoch:1000  d_loss:0.0885  g_loss:5.6761
# /var/folders/5v/mvnwz1m90_bggm2dg0n3cmb80000gn/T/ipykernel_8374/1261082867.py:90: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(5, 5)
# epoch:1001  d_loss:0.0820  g_loss:4.8462
# epoch:1002  d_loss:0.0740  g_loss:5.3317
# epoch:1003  d_loss:0.0805  g_loss:5.2534
# epoch:1004  d_loss:0.0383  g_loss:6.5058
# epoch:1005  d_loss:0.1023  g_loss:5.8505
# epoch:1006  d_loss:0.1028  g_loss:4.3653
# epoch:1007  d_loss:0.0536  g_loss:5.0334
# epoch:1008  d_loss:0.1003  g_loss:4.6546
# epoch:1009  d_loss:0.1081  g_loss:4.9858
# epoch:1010  d_loss:0.0783  g_loss:5.7395
# epoch:1011  d_loss:0.0698  g_loss:5.7990
# epoch:1012  d_loss:0.0792  g_loss:6.1084
# epoch:1013  d_loss:0.1238  g_loss:4.8390
# epoch:1014  d_loss:0.0924  g_loss:4.3468
# epoch:1015  d_loss:0.0325  g_loss:5.1847
# epoch:1016  d_loss:0.0696  g_loss:6.4062
# epoch:1017  d_loss:0.0962  g_loss:6.6279
# epoch:1018  d_loss:0.0881  g_loss:6.7377
# epoch:1019  d_loss:0.1015  g_loss:4.7146
# epoch:1020  d_loss:0.1108  g_loss:4.8188
# epoch:1021  d_loss:0.1114  g_loss:4.9975
# epoch:1022  d_loss:0.0661  g_loss:5.3968
# epoch:1023  d_loss:0.0397  g_loss:5.9835
# epoch:1024  d_loss:0.0572  g_loss:5.7053
# epoch:1025  d_loss:0.0949  g_loss:5.1183
# epoch:1026  d_loss:0.0799  g_loss:4.5322
# epoch:1027  d_loss:0.2106  g_loss:4.4276
# epoch:1028  d_loss:0.0861  g_loss:5.2143
# epoch:1029  d_loss:0.0485  g_loss:6.0518
# epoch:1030  d_loss:0.1778  g_loss:4.5801
# epoch:1031  d_loss:0.1318  g_loss:4.5108
# epoch:1032  d_loss:0.0436  g_loss:4.8365
# epoch:1033  d_loss:0.0489  g_loss:5.0306
# epoch:1034  d_loss:0.0649  g_loss:5.6591
# epoch:1035  d_loss:0.0737  g_loss:5.0548
# epoch:1036  d_loss:0.0503  g_loss:5.4660
# epoch:1037  d_loss:0.0656  g_loss:4.6495
# epoch:1038  d_loss:0.0809  g_loss:5.0711
# epoch:1039  d_loss:0.0321  g_loss:6.6721
# epoch:1040  d_loss:0.1429  g_loss:5.8722
# epoch:1041  d_loss:0.1310  g_loss:4.9185
# epoch:1042  d_loss:0.1794  g_loss:4.3915
# epoch:1043  d_loss:0.0360  g_loss:4.6234
# epoch:1044  d_loss:0.0638  g_loss:5.3579
# epoch:1045  d_loss:0.0887  g_loss:5.2452
# epoch:1046  d_loss:0.1394  g_loss:5.1720
# epoch:1047  d_loss:0.0713  g_loss:5.3475
# epoch:1048  d_loss:0.0716  g_loss:5.5834
# epoch:1049  d_loss:0.0820  g_loss:4.0852
# epoch:1050  d_loss:0.0400  g_loss:5.3233
# epoch:1051  d_loss:0.0807  g_loss:4.6404
# epoch:1052  d_loss:0.1491  g_loss:5.6131
# epoch:1053  d_loss:0.0722  g_loss:5.2289
# epoch:1054  d_loss:0.0947  g_loss:5.9705
# epoch:1055  d_loss:0.0537  g_loss:5.4410
# epoch:1056  d_loss:0.0898  g_loss:5.1542
# epoch:1057  d_loss:0.0391  g_loss:5.1949
# epoch:1058  d_loss:0.0539  g_loss:4.9391
# epoch:1059  d_loss:0.1297  g_loss:4.7354
# epoch:1060  d_loss:0.0510  g_loss:5.4605
# epoch:1061  d_loss:0.0432  g_loss:4.7235
# epoch:1062  d_loss:0.0404  g_loss:5.5985
# epoch:1063  d_loss:0.0654  g_loss:6.2529
# epoch:1064  d_loss:0.1207  g_loss:5.3906
# epoch:1065  d_loss:0.0715  g_loss:4.7915
# epoch:1066  d_loss:0.0428  g_loss:4.3864
# epoch:1067  d_loss:0.1163  g_loss:4.6264
# epoch:1068  d_loss:0.0440  g_loss:6.8288
# epoch:1069  d_loss:0.0426  g_loss:6.4747
# epoch:1070  d_loss:0.0497  g_loss:6.3977
# epoch:1071  d_loss:0.0875  g_loss:6.3403
# epoch:1072  d_loss:0.0910  g_loss:4.4502
# epoch:1073  d_loss:0.0872  g_loss:4.6441
# epoch:1074  d_loss:0.1016  g_loss:4.3732
# epoch:1075  d_loss:0.0639  g_loss:5.0800
# epoch:1076  d_loss:0.0320  g_loss:6.9415
# epoch:1077  d_loss:0.0950  g_loss:5.8570
# epoch:1078  d_loss:0.0850  g_loss:5.4618
# epoch:1079  d_loss:0.0828  g_loss:4.5053
# epoch:1080  d_loss:0.1747  g_loss:4.7250
# epoch:1081  d_loss:0.0576  g_loss:6.4097
# epoch:1082  d_loss:0.1387  g_loss:5.6970
# epoch:1083  d_loss:0.0955  g_loss:5.5144
# epoch:1084  d_loss:0.0383  g_loss:5.8797
# epoch:1085  d_loss:0.2245  g_loss:4.8486
# epoch:1086  d_loss:0.0966  g_loss:4.3365
# epoch:1087  d_loss:0.0448  g_loss:5.4596
# epoch:1088  d_loss:0.0600  g_loss:5.3393
# epoch:1089  d_loss:0.0529  g_loss:5.9846
# epoch:1090  d_loss:0.0980  g_loss:5.3262
# epoch:1091  d_loss:0.0576  g_loss:4.8752
# epoch:1092  d_loss:0.0338  g_loss:4.6670
# epoch:1093  d_loss:0.0388  g_loss:5.3667
# epoch:1094  d_loss:0.0496  g_loss:5.9198
# epoch:1095  d_loss:0.0386  g_loss:5.7560
# epoch:1096  d_loss:0.0986  g_loss:5.8693
# epoch:1097  d_loss:0.0580  g_loss:4.5324
# epoch:1098  d_loss:0.0480  g_loss:4.7693
# epoch:1099  d_loss:0.0602  g_loss:5.0632
# epoch:1100  d_loss:0.2062  g_loss:5.6083
# epoch:1101  d_loss:0.0915  g_loss:7.8912
# epoch:1102  d_loss:0.0975  g_loss:7.8879
# epoch:1103  d_loss:0.1738  g_loss:6.0136
# epoch:1104  d_loss:0.0808  g_loss:4.2225
# epoch:1105  d_loss:0.0815  g_loss:4.3351
# epoch:1106  d_loss:0.0579  g_loss:5.0007
# epoch:1107  d_loss:0.0296  g_loss:5.8246
# epoch:1108  d_loss:0.0918  g_loss:5.5445
# epoch:1109  d_loss:0.0780  g_loss:5.0538
# epoch:1110  d_loss:0.1270  g_loss:5.5706
# epoch:1111  d_loss:0.0956  g_loss:5.0342
# epoch:1112  d_loss:0.0539  g_loss:6.3174
# epoch:1113  d_loss:0.1075  g_loss:6.0244
# epoch:1114  d_loss:0.1043  g_loss:4.3177
# epoch:1115  d_loss:0.0373  g_loss:4.7333
# epoch:1116  d_loss:0.0848  g_loss:5.4229
# epoch:1117  d_loss:0.0318  g_loss:6.1367
# epoch:1118  d_loss:0.0602  g_loss:6.5061
# epoch:1119  d_loss:0.1105  g_loss:5.4820
# epoch:1120  d_loss:0.1254  g_loss:4.4904
# epoch:1121  d_loss:0.1259  g_loss:4.9559
# epoch:1122  d_loss:0.0464  g_loss:4.6953
# epoch:1123  d_loss:0.0660  g_loss:4.7723
# epoch:1124  d_loss:0.1557  g_loss:4.6837
# epoch:1125  d_loss:0.0952  g_loss:5.7041
# epoch:1126  d_loss:0.0969  g_loss:5.4651
# epoch:1127  d_loss:0.0484  g_loss:6.1501
# epoch:1128  d_loss:0.1142  g_loss:5.9736
# epoch:1129  d_loss:0.0853  g_loss:6.6276
# epoch:1130  d_loss:0.0573  g_loss:6.3422
# epoch:1131  d_loss:0.1356  g_loss:4.7566
# epoch:1132  d_loss:0.0748  g_loss:5.3287
# epoch:1133  d_loss:0.0229  g_loss:5.5410
# epoch:1134  d_loss:0.0424  g_loss:5.7900
# epoch:1135  d_loss:0.0662  g_loss:4.7271
# epoch:1136  d_loss:0.1064  g_loss:5.0422
# epoch:1137  d_loss:0.0622  g_loss:5.5009
# epoch:1138  d_loss:0.0807  g_loss:5.0842
# epoch:1139  d_loss:0.0767  g_loss:4.8967
# epoch:1140  d_loss:0.0950  g_loss:4.9780
# epoch:1141  d_loss:0.0578  g_loss:6.3398
# epoch:1142  d_loss:0.0365  g_loss:5.6703
# epoch:1143  d_loss:0.0740  g_loss:5.9211
# epoch:1144  d_loss:0.0963  g_loss:5.4326
# epoch:1145  d_loss:0.0500  g_loss:5.3119
# epoch:1146  d_loss:0.0629  g_loss:5.0258
# epoch:1147  d_loss:0.0364  g_loss:6.1610
# epoch:1148  d_loss:0.1081  g_loss:5.2736
# epoch:1149  d_loss:0.0934  g_loss:4.7776
# epoch:1150  d_loss:0.0956  g_loss:5.2584
# epoch:1151  d_loss:0.0981  g_loss:5.0908
# epoch:1152  d_loss:0.0263  g_loss:5.6387
# epoch:1153  d_loss:0.0321  g_loss:6.9209
# epoch:1154  d_loss:0.0535  g_loss:5.6659
# epoch:1155  d_loss:0.0590  g_loss:5.4700
# epoch:1156  d_loss:0.0517  g_loss:4.7681
# epoch:1157  d_loss:0.1919  g_loss:4.4285
# epoch:1158  d_loss:0.0349  g_loss:6.8294
# epoch:1159  d_loss:0.1384  g_loss:6.8909
# epoch:1160  d_loss:0.1436  g_loss:4.4824
# epoch:1161  d_loss:0.1084  g_loss:3.8700
# epoch:1162  d_loss:0.1189  g_loss:4.4942
# epoch:1163  d_loss:0.1203  g_loss:6.4746
# epoch:1164  d_loss:0.1409  g_loss:6.6543
# epoch:1165  d_loss:0.1170  g_loss:4.9896
# epoch:1166  d_loss:0.0546  g_loss:4.9343
# epoch:1167  d_loss:0.1112  g_loss:4.8082
# epoch:1168  d_loss:0.0808  g_loss:4.7653
# epoch:1169  d_loss:0.0686  g_loss:5.2130
# ...
# epoch:1611  d_loss:0.1657  g_loss:3.8411
# epoch:1612  d_loss:0.0975  g_loss:6.0666
# epoch:1613  d_loss:0.0388  g_loss:7.2816
# epoch:1614  d_loss:0.1468  g_loss:7.1136
# epoch:1615  d_loss:0.1093  g_loss:5.5514
# epoch:1616  d_loss:0.1212  g_loss:5.1055
# epoch:1617  d_loss:0.1348  g_loss:5.8136
# epoch:1618  d_loss:0.0278  g_loss:6.1912
# epoch:1619  d_loss:0.1531  g_loss:5.8907
# epoch:1620  d_loss:0.1272  g_loss:5.5696
# epoch:1621  d_loss:0.1142  g_loss:5.9244
# epoch:1622  d_loss:0.0506  g_loss:4.4805
# epoch:1623  d_loss:0.0963  g_loss:4.8097
# epoch:1624  d_loss:0.1088  g_loss:5.3686
# epoch:1625  d_loss:0.1140  g_loss:5.5238
# epoch:1626  d_loss:0.0252  g_loss:6.6939
# epoch:1627  d_loss:0.1157  g_loss:6.5020
# epoch:1628  d_loss:0.1725  g_loss:6.0870
# epoch:1629  d_loss:0.0621  g_loss:5.3985
# epoch:1630  d_loss:0.1006  g_loss:4.5261
# epoch:1631  d_loss:0.1804  g_loss:5.2792
# epoch:1632  d_loss:0.0809  g_loss:6.9254
# epoch:1633  d_loss:0.1081  g_loss:6.3055
# epoch:1634  d_loss:0.0763  g_loss:6.4649
# epoch:1635  d_loss:0.2335  g_loss:5.6796
# epoch:1636  d_loss:0.1040  g_loss:5.0718
# epoch:1637  d_loss:0.0883  g_loss:5.3784
# epoch:1638  d_loss:0.0624  g_loss:6.2043
# epoch:1639  d_loss:0.1169  g_loss:6.3263
# epoch:1640  d_loss:0.0760  g_loss:5.9536
# epoch:1641  d_loss:0.0999  g_loss:4.7518
# epoch:1642  d_loss:0.0879  g_loss:4.3534
# epoch:1643  d_loss:0.0593  g_loss:4.6840
# epoch:1644  d_loss:0.0436  g_loss:4.1853
# epoch:1645  d_loss:0.0550  g_loss:5.8362
# epoch:1646  d_loss:0.0716  g_loss:5.5584
# epoch:1647  d_loss:0.0938  g_loss:5.0537
# epoch:1648  d_loss:0.0469  g_loss:5.9026
# epoch:1649  d_loss:0.0859  g_loss:5.8230
# epoch:1650  d_loss:0.1009  g_loss:4.8759
# epoch:1651  d_loss:0.0724  g_loss:5.0282
# epoch:1652  d_loss:0.0537  g_loss:4.7087
# epoch:1653  d_loss:0.0882  g_loss:5.0621
# epoch:1654  d_loss:0.0875  g_loss:5.6998
# epoch:1655  d_loss:0.0288  g_loss:7.1049
# epoch:1656  d_loss:0.0955  g_loss:6.8303
# epoch:1657  d_loss:0.0518  g_loss:5.3645
# epoch:1658  d_loss:0.0842  g_loss:4.3617
# epoch:1659  d_loss:0.0486  g_loss:5.3323
# epoch:1660  d_loss:0.0763  g_loss:5.3453
# epoch:1661  d_loss:0.0937  g_loss:5.9726
# epoch:1662  d_loss:0.0569  g_loss:6.2362
# epoch:1663  d_loss:0.0813  g_loss:5.8744
# epoch:1664  d_loss:0.1851  g_loss:5.7856
# epoch:1665  d_loss:0.0434  g_loss:6.1516
# epoch:1666  d_loss:0.0767  g_loss:6.6869
# epoch:1667  d_loss:0.1174  g_loss:5.3258
# epoch:1668  d_loss:0.1062  g_loss:4.0349
# epoch:1669  d_loss:0.1378  g_loss:5.3256
# epoch:1670  d_loss:0.0269  g_loss:5.4651
# epoch:1671  d_loss:0.0344  g_loss:6.3117
# epoch:1672  d_loss:0.0689  g_loss:6.9413
# epoch:1673  d_loss:0.1535  g_loss:6.0045
# epoch:1674  d_loss:0.0915  g_loss:4.9735
# epoch:1675  d_loss:0.1139  g_loss:4.8057
# epoch:1676  d_loss:0.0450  g_loss:5.1052
# epoch:1677  d_loss:0.0629  g_loss:4.9200
# epoch:1678  d_loss:0.0704  g_loss:5.3605
# epoch:1679  d_loss:0.0435  g_loss:6.7173
# epoch:1680  d_loss:0.0709  g_loss:5.9554
# epoch:1681  d_loss:0.0798  g_loss:6.3010
# epoch:1682  d_loss:0.0661  g_loss:5.4860
# epoch:1683  d_loss:0.0807  g_loss:5.3351
# epoch:1684  d_loss:0.0416  g_loss:5.8017
# epoch:1685  d_loss:0.1067  g_loss:5.3112
# epoch:1686  d_loss:0.0408  g_loss:5.8338
# epoch:1687  d_loss:0.0753  g_loss:5.5333
# epoch:1688  d_loss:0.0676  g_loss:5.8974
# epoch:1689  d_loss:0.2046  g_loss:4.9396
# epoch:1690  d_loss:0.0474  g_loss:7.2651
# epoch:1691  d_loss:0.0967  g_loss:5.5104
# epoch:1692  d_loss:0.0880  g_loss:5.6375
# epoch:1693  d_loss:0.0779  g_loss:5.2320
# epoch:1694  d_loss:0.0805  g_loss:5.4650
# epoch:1695  d_loss:0.0679  g_loss:5.2492
# epoch:1696  d_loss:0.0423  g_loss:5.1170
# epoch:1697  d_loss:0.0723  g_loss:5.0715
# epoch:1698  d_loss:0.1419  g_loss:5.1267
# epoch:1699  d_loss:0.0610  g_loss:6.4534
# epoch:1700  d_loss:0.1264  g_loss:6.1009
# epoch:1701  d_loss:0.1740  g_loss:5.1203
# epoch:1702  d_loss:0.0651  g_loss:5.0492
# epoch:1703  d_loss:0.0554  g_loss:5.0426
# epoch:1704  d_loss:0.0732  g_loss:4.6523
# epoch:1705  d_loss:0.0650  g_loss:6.0261
# epoch:1706  d_loss:0.1561  g_loss:6.0336
# epoch:1707  d_loss:0.0935  g_loss:6.7365
# epoch:1708  d_loss:0.0706  g_loss:6.6998
# epoch:1709  d_loss:0.1181  g_loss:4.1701
# epoch:1710  d_loss:0.1452  g_loss:4.1351
# epoch:1711  d_loss:0.1223  g_loss:4.4724
# epoch:1712  d_loss:0.1608  g_loss:6.2120
# epoch:1713  d_loss:0.1252  g_loss:6.0142
# epoch:1714  d_loss:0.0662  g_loss:7.0441
# epoch:1715  d_loss:0.0881  g_loss:6.6357
# epoch:1716  d_loss:0.0944  g_loss:5.1869
# epoch:1717  d_loss:0.1534  g_loss:4.4959
# epoch:1718  d_loss:0.0296  g_loss:4.0726
# epoch:1719  d_loss:0.0871  g_loss:4.2045
# epoch:1720  d_loss:0.0410  g_loss:6.0840
# epoch:1721  d_loss:0.0678  g_loss:5.5295
# epoch:1722  d_loss:0.0482  g_loss:6.2618
# epoch:1723  d_loss:0.0432  g_loss:5.6286
# epoch:1724  d_loss:0.0507  g_loss:5.9122
# epoch:1725  d_loss:0.0457  g_loss:5.9278
# epoch:1726  d_loss:0.0910  g_loss:6.1252
# epoch:1727  d_loss:0.0980  g_loss:5.9595
# epoch:1728  d_loss:0.1058  g_loss:4.7291
# epoch:1729  d_loss:0.1095  g_loss:5.3652
# epoch:1730  d_loss:0.0909  g_loss:5.8897
# epoch:1731  d_loss:0.0679  g_loss:5.3840
# epoch:1732  d_loss:0.1219  g_loss:5.8277
# epoch:1733  d_loss:0.0411  g_loss:6.6788
# epoch:1734  d_loss:0.0968  g_loss:7.2023
# epoch:1735  d_loss:0.0999  g_loss:7.1991
# epoch:1736  d_loss:0.0771  g_loss:5.7306
# epoch:1737  d_loss:0.1225  g_loss:5.8078
# epoch:1738  d_loss:0.0670  g_loss:5.8535
# epoch:1739  d_loss:0.0796  g_loss:6.1766
# epoch:1740  d_loss:0.0816  g_loss:7.3676
# epoch:1741  d_loss:0.0998  g_loss:6.9911
# epoch:1742  d_loss:0.1727  g_loss:6.5284
# epoch:1743  d_loss:0.1410  g_loss:4.0475
# epoch:1744  d_loss:0.1125  g_loss:3.3186
# epoch:1745  d_loss:0.1456  g_loss:4.7434
# epoch:1746  d_loss:0.0309  g_loss:7.1141
# epoch:1747  d_loss:0.0833  g_loss:6.5901
# epoch:1748  d_loss:0.0624  g_loss:6.4215
# epoch:1749  d_loss:0.1428  g_loss:4.9852
# epoch:1750  d_loss:0.1081  g_loss:4.8451
# epoch:1751  d_loss:0.1951  g_loss:4.6153
# epoch:1752  d_loss:0.1021  g_loss:5.9919
# epoch:1753  d_loss:0.1594  g_loss:6.0366
# epoch:1754  d_loss:0.1211  g_loss:5.3933
# epoch:1755  d_loss:0.0460  g_loss:4.8871
# epoch:1756  d_loss:0.1408  g_loss:3.5103
# epoch:1757  d_loss:0.1244  g_loss:5.4641
# epoch:1758  d_loss:0.0920  g_loss:6.9014
# epoch:1759  d_loss:0.1133  g_loss:6.6586
# epoch:1760  d_loss:0.0769  g_loss:6.7717
# epoch:1761  d_loss:0.1360  g_loss:4.5349
# epoch:1762  d_loss:0.0579  g_loss:5.0369
# epoch:1763  d_loss:0.0894  g_loss:4.8907
# epoch:1764  d_loss:0.0716  g_loss:5.1964
# epoch:1765  d_loss:0.0838  g_loss:6.1338
# epoch:1766  d_loss:0.0771  g_loss:6.1867
# epoch:1767  d_loss:0.0857  g_loss:6.3597
# epoch:1768  d_loss:0.0293  g_loss:6.4533
# epoch:1769  d_loss:0.0789  g_loss:6.7802
# epoch:1770  d_loss:0.0517  g_loss:5.8694
# epoch:1771  d_loss:0.0377  g_loss:6.6493
# epoch:1772  d_loss:0.1614  g_loss:5.2943
# epoch:1773  d_loss:0.0619  g_loss:6.0004
# epoch:1774  d_loss:0.0294  g_loss:6.5349
# epoch:1775  d_loss:0.0820  g_loss:6.9989
# epoch:1776  d_loss:0.0991  g_loss:6.2596
# epoch:1777  d_loss:0.0825  g_loss:5.2708
# epoch:1778  d_loss:0.0674  g_loss:5.3988
# epoch:1779  d_loss:0.1228  g_loss:5.5026
# epoch:1780  d_loss:0.0516  g_loss:6.6385
# epoch:1781  d_loss:0.1161  g_loss:6.0221
# epoch:1782  d_loss:0.1637  g_loss:6.3629
# epoch:1783  d_loss:0.0792  g_loss:6.0667
# epoch:1784  d_loss:0.1095  g_loss:5.5434
# epoch:1785  d_loss:0.0491  g_loss:5.7737
# epoch:1786  d_loss:0.0788  g_loss:5.3990
# epoch:1787  d_loss:0.0722  g_loss:5.9042
# epoch:1788  d_loss:0.0844  g_loss:6.2038
# epoch:1789  d_loss:0.0780  g_loss:5.5582
# epoch:1790  d_loss:0.0576  g_loss:5.7532
# epoch:1791  d_loss:0.0971  g_loss:5.1341
# epoch:1792  d_loss:0.0605  g_loss:7.0049
# epoch:1793  d_loss:0.2222  g_loss:5.2248
# epoch:1794  d_loss:0.0546  g_loss:5.2469
# epoch:1795  d_loss:0.1193  g_loss:5.1685
# epoch:1796  d_loss:0.0308  g_loss:6.4924
# epoch:1797  d_loss:0.0988  g_loss:5.6076
# epoch:1798  d_loss:0.1484  g_loss:5.6190
# epoch:1799  d_loss:0.0535  g_loss:5.7182
# epoch:1800  d_loss:0.0647  g_loss:5.9020
# epoch:1801  d_loss:0.0553  g_loss:5.6554
# epoch:1802  d_loss:0.0728  g_loss:4.7348
# epoch:1803  d_loss:0.1021  g_loss:5.1070
# epoch:1804  d_loss:0.0874  g_loss:5.5104
# epoch:1805  d_loss:0.1115  g_loss:6.1031
# epoch:1806  d_loss:0.1290  g_loss:6.2077
# epoch:1807  d_loss:0.1042  g_loss:6.0235
# epoch:1808  d_loss:0.0540  g_loss:5.5757
# epoch:1809  d_loss:0.0943  g_loss:5.2907
# epoch:1810  d_loss:0.0494  g_loss:7.0950
# epoch:1811  d_loss:0.1155  g_loss:7.0965
# epoch:1812  d_loss:0.0884  g_loss:6.3128
# epoch:1813  d_loss:0.0916  g_loss:5.6922
# epoch:1814  d_loss:0.0664  g_loss:5.6151
# epoch:1815  d_loss:0.0865  g_loss:4.6350
# epoch:1816  d_loss:0.0569  g_loss:4.4435
# epoch:1817  d_loss:0.0510  g_loss:5.2847
# epoch:1818  d_loss:0.0790  g_loss:4.8126
# epoch:1819  d_loss:0.0592  g_loss:5.8495
# epoch:1820  d_loss:0.0930  g_loss:6.2582
# epoch:1821  d_loss:0.1518  g_loss:4.7053
# epoch:1822  d_loss:0.0904  g_loss:5.0667
# epoch:1823  d_loss:0.0410  g_loss:5.8121
# epoch:1824  d_loss:0.0853  g_loss:6.2016
# epoch:1825  d_loss:0.0614  g_loss:6.8723
# epoch:1826  d_loss:0.0454  g_loss:6.6627
# epoch:1827  d_loss:0.1468  g_loss:5.4580
# epoch:1828  d_loss:0.0841  g_loss:5.2801
# epoch:1829  d_loss:0.0900  g_loss:4.9780
# epoch:1830  d_loss:0.0453  g_loss:5.3565
# epoch:1831  d_loss:0.0678  g_loss:4.8075
# epoch:1832  d_loss:0.0698  g_loss:6.5475
# epoch:1833  d_loss:0.1190  g_loss:6.9859
# epoch:1834  d_loss:0.0699  g_loss:7.4952
# epoch:1835  d_loss:0.0885  g_loss:6.7997
# epoch:1836  d_loss:0.0762  g_loss:5.1506
# epoch:1837  d_loss:0.0882  g_loss:5.2242
# epoch:1838  d_loss:0.1042  g_loss:4.8467
# epoch:1839  d_loss:0.1080  g_loss:5.1441
# epoch:1840  d_loss:0.1034  g_loss:6.3187
# epoch:1841  d_loss:0.0447  g_loss:7.6588
# epoch:1842  d_loss:0.1655  g_loss:7.9611
# epoch:1843  d_loss:0.1408  g_loss:5.2655
# epoch:1844  d_loss:0.1943  g_loss:5.0683
# epoch:1845  d_loss:0.1049  g_loss:5.5678
# epoch:1846  d_loss:0.0234  g_loss:5.6341
# epoch:1847  d_loss:0.0655  g_loss:6.2650
# epoch:1848  d_loss:0.2303  g_loss:5.6072
# epoch:1849  d_loss:0.0563  g_loss:5.9013
# epoch:1850  d_loss:0.0854  g_loss:4.7804
# epoch:1851  d_loss:0.0814  g_loss:5.3641
# epoch:1852  d_loss:0.0468  g_loss:4.8840
# epoch:1853  d_loss:0.0324  g_loss:6.1440
# epoch:1854  d_loss:0.1166  g_loss:5.5398
# epoch:1855  d_loss:0.0585  g_loss:6.8795
# epoch:1856  d_loss:0.0493  g_loss:6.6529
# epoch:1857  d_loss:0.0942  g_loss:5.8880
# epoch:1858  d_loss:0.0775  g_loss:4.4001
# epoch:1859  d_loss:0.1181  g_loss:5.0433
# epoch:1860  d_loss:0.0971  g_loss:6.1544
# epoch:1861  d_loss:0.0892  g_loss:6.1517
# epoch:1862  d_loss:0.0697  g_loss:5.4939
# epoch:1863  d_loss:0.0811  g_loss:4.9023
# epoch:1864  d_loss:0.0693  g_loss:4.0110
# epoch:1865  d_loss:0.1217  g_loss:4.3087
# epoch:1866  d_loss:0.0600  g_loss:5.5487
# epoch:1867  d_loss:0.0745  g_loss:7.0704
# epoch:1868  d_loss:0.0590  g_loss:6.4764
# epoch:1869  d_loss:0.1065  g_loss:6.0890
# epoch:1870  d_loss:0.0780  g_loss:5.0953
# epoch:1871  d_loss:0.1111  g_loss:5.4267
# epoch:1872  d_loss:0.0887  g_loss:5.1453
# epoch:1873  d_loss:0.0212  g_loss:5.7762
# epoch:1874  d_loss:0.1040  g_loss:7.1395
# epoch:1875  d_loss:0.1185  g_loss:5.8979
# epoch:1876  d_loss:0.0448  g_loss:7.1293
# epoch:1877  d_loss:0.0517  g_loss:5.4154
# epoch:1878  d_loss:0.0810  g_loss:4.3206
# epoch:1879  d_loss:0.0706  g_loss:4.6606
# epoch:1880  d_loss:0.0327  g_loss:5.4244
# epoch:1881  d_loss:0.1550  g_loss:5.0832
# epoch:1882  d_loss:0.1022  g_loss:7.8050
# epoch:1883  d_loss:0.1046  g_loss:7.3486
# epoch:1884  d_loss:0.0925  g_loss:6.6078
# epoch:1885  d_loss:0.0770  g_loss:5.1729
# epoch:1886  d_loss:0.1007  g_loss:4.6440
# epoch:1887  d_loss:0.1891  g_loss:5.2279
# epoch:1888  d_loss:0.0429  g_loss:7.7657
# epoch:1889  d_loss:0.0944  g_loss:6.4080
# epoch:1890  d_loss:0.0856  g_loss:6.8209
# epoch:1891  d_loss:0.0951  g_loss:5.4409
# epoch:1892  d_loss:0.0487  g_loss:4.9710
# epoch:1893  d_loss:0.0480  g_loss:5.3461
# epoch:1894  d_loss:0.0747  g_loss:4.7703
# epoch:1895  d_loss:0.1357  g_loss:5.9490
# epoch:1896  d_loss:0.1297  g_loss:6.5892
# epoch:1897  d_loss:0.0966  g_loss:6.3764
# epoch:1898  d_loss:0.0972  g_loss:6.3868
# epoch:1899  d_loss:0.1421  g_loss:5.5158
# epoch:1900  d_loss:0.0636  g_loss:5.3944
# epoch:1901  d_loss:0.0554  g_loss:5.0452
# epoch:1902  d_loss:0.1111  g_loss:4.6847
# epoch:1903  d_loss:0.1086  g_loss:5.3035
# epoch:1904  d_loss:0.0415  g_loss:5.1499
# epoch:1905  d_loss:0.2155  g_loss:5.3033
# epoch:1906  d_loss:0.1240  g_loss:7.4994
# epoch:1907  d_loss:0.0848  g_loss:6.3110
# epoch:1908  d_loss:0.2403  g_loss:5.3488
# epoch:1909  d_loss:0.0956  g_loss:4.7480
# epoch:1910  d_loss:0.0891  g_loss:4.9509
# epoch:1911  d_loss:0.1048  g_loss:4.8550
# epoch:1912  d_loss:0.0671  g_loss:5.7958
# epoch:1913  d_loss:0.0375  g_loss:6.8580
# epoch:1914  d_loss:0.1299  g_loss:6.3058
# epoch:1915  d_loss:0.0930  g_loss:5.5678
# epoch:1916  d_loss:0.0548  g_loss:5.6934
# epoch:1917  d_loss:0.1251  g_loss:5.5527
# epoch:1918  d_loss:0.0484  g_loss:6.6295
# epoch:1919  d_loss:0.0940  g_loss:5.5852
# epoch:1920  d_loss:0.0824  g_loss:5.7833
# epoch:1921  d_loss:0.0480  g_loss:5.6802
# epoch:1922  d_loss:0.0614  g_loss:4.7167
# epoch:1923  d_loss:0.0463  g_loss:4.8947
# epoch:1924  d_loss:0.0954  g_loss:5.8979
# epoch:1925  d_loss:0.1275  g_loss:4.9163
# epoch:1926  d_loss:0.0972  g_loss:4.8991
# epoch:1927  d_loss:0.1161  g_loss:4.9889
# epoch:1928  d_loss:0.1343  g_loss:6.2371
# epoch:1929  d_loss:0.0452  g_loss:6.8747
# epoch:1930  d_loss:0.0791  g_loss:5.9672
# epoch:1931  d_loss:0.1018  g_loss:5.7057
# epoch:1932  d_loss:0.1081  g_loss:4.9587
# epoch:1933  d_loss:0.0756  g_loss:4.7688
# epoch:1934  d_loss:0.1037  g_loss:6.1681
# epoch:1935  d_loss:0.1137  g_loss:7.0701
# epoch:1936  d_loss:0.1045  g_loss:6.3160
# epoch:1937  d_loss:0.0861  g_loss:6.3591
# epoch:1938  d_loss:0.0916  g_loss:4.8596
# epoch:1939  d_loss:0.0881  g_loss:5.2505
# epoch:1940  d_loss:0.0561  g_loss:5.9982
# epoch:1941  d_loss:0.0644  g_loss:6.1180
# epoch:1942  d_loss:0.0910  g_loss:6.0430
# epoch:1943  d_loss:0.0755  g_loss:5.7159
# epoch:1944  d_loss:0.0809  g_loss:5.8677
# epoch:1945  d_loss:0.0532  g_loss:6.1069
# epoch:1946  d_loss:0.0142  g_loss:6.0567
# epoch:1947  d_loss:0.0856  g_loss:6.0934
# epoch:1948  d_loss:0.0843  g_loss:4.6327
# epoch:1949  d_loss:0.0640  g_loss:4.6815
# epoch:1950  d_loss:0.0872  g_loss:3.8724
# epoch:1951  d_loss:0.0675  g_loss:5.9124
# epoch:1952  d_loss:0.0422  g_loss:6.1437
# epoch:1953  d_loss:0.0708  g_loss:6.8394
# epoch:1954  d_loss:0.1055  g_loss:5.9668
# epoch:1955  d_loss:0.0486  g_loss:5.7848
# epoch:1956  d_loss:0.0565  g_loss:5.6551
# epoch:1957  d_loss:0.0580  g_loss:5.4663
# epoch:1958  d_loss:0.0392  g_loss:6.0881
# epoch:1959  d_loss:0.0761  g_loss:5.5894
# epoch:1960  d_loss:0.1314  g_loss:5.8205
# epoch:1961  d_loss:0.0648  g_loss:6.9289
# epoch:1962  d_loss:0.0742  g_loss:6.6263
# epoch:1963  d_loss:0.0911  g_loss:5.9511
# epoch:1964  d_loss:0.0853  g_loss:5.4116
# epoch:1965  d_loss:0.1026  g_loss:5.1387
# epoch:1966  d_loss:0.1077  g_loss:6.0002
# epoch:1967  d_loss:0.0369  g_loss:7.0940
# epoch:1968  d_loss:0.1154  g_loss:6.5506
# epoch:1969  d_loss:0.0794  g_loss:5.1281
# epoch:1970  d_loss:0.0852  g_loss:5.6206
# epoch:1971  d_loss:0.0661  g_loss:5.3349
# epoch:1972  d_loss:0.1126  g_loss:6.3336
# epoch:1973  d_loss:0.1042  g_loss:7.2612
# epoch:1974  d_loss:0.1069  g_loss:6.5014
# epoch:1975  d_loss:0.0774  g_loss:5.9117
# epoch:1976  d_loss:0.0966  g_loss:5.9885
# epoch:1977  d_loss:0.0940  g_loss:6.1024
# epoch:1978  d_loss:0.0458  g_loss:6.3201
# epoch:1979  d_loss:0.1175  g_loss:6.7901
# epoch:1980  d_loss:0.1006  g_loss:5.7436
# epoch:1981  d_loss:0.0707  g_loss:5.2500
# epoch:1982  d_loss:0.0316  g_loss:4.3188
# epoch:1983  d_loss:0.1708  g_loss:4.8767
# epoch:1984  d_loss:0.0272  g_loss:5.5537
# epoch:1985  d_loss:0.0828  g_loss:7.0229
# epoch:1986  d_loss:0.1439  g_loss:5.2478
# epoch:1987  d_loss:0.1184  g_loss:5.5706
# epoch:1988  d_loss:0.0809  g_loss:5.7530
# epoch:1989  d_loss:0.0729  g_loss:5.4750
# epoch:1990  d_loss:0.0776  g_loss:5.1926
# epoch:1991  d_loss:0.1391  g_loss:5.6897
# epoch:1992  d_loss:0.1467  g_loss:6.9011
# epoch:1993  d_loss:0.0714  g_loss:7.9309
# epoch:1994  d_loss:0.1452  g_loss:5.7170
# epoch:1995  d_loss:0.1334  g_loss:3.8211
# epoch:1996  d_loss:0.2097  g_loss:4.1934
# epoch:1997  d_loss:0.0697  g_loss:4.9178
# epoch:1998  d_loss:0.1150  g_loss:5.8295
# epoch:1999  d_loss:0.0545  g_loss:6.8771
# epoch:2000  d_loss:0.1562  g_loss:6.7300

# %% [markdown]
# ### 문제점
# 판별자 이미지를 랜덤으로 추출해서 일정 횟수 이상 반복을 해도 퀄리티가 좋아지지 않음
# 800번 이미지와 이후 이미지의 퀄리티에 눈에 띄는 차이가 없음
# 완벽하게 인식 가능한 숫자 형태가 되었다가도 횟수가 반복되면서 다시 읽을 수 없는 이미지로 변경됨
#
# ### 개선 아이디어
# 판별용 이미지를 숫자 샘플별로 구분하고,
# 각 랜덤 이미지를 변경 대상 숫자를 랜덤 지정한 후 대상 숫자 샘플 내에서 이미지를 판별 및 생성하도록 함
# 학습 과정에서 숫자의 판별과 정확도를 측정해서 일정 기준을 통과하면 해당 이미지의 학습을 중단
# 모든 이미지가 정확도 기준을 통과하면 모델링을 중지

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더

# %% [markdown]
# ### 실습: 오토인코더 실습하기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np

# MNIST 데이터셋을 불러옵니다.
(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
#shape - 현재 배열의 차원별 요소값을 리턴
#X_train.shape[0] = 6000개의 이미지 배열로 1차원에는 6000
#즉, reshape(6000, 28, 28, 1)의 4차원 배열로 변환됨

X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분이 이어집니다. 
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인해 봅니다.
autoencoder.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 8)           584
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))


# 앞서 만든 오토인코더 모델에 집어 넣습니다.
ae_imgs = autoencoder.predict(X_test)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.2269 - val_loss: 0.1475
# Epoch 2/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.1369 - val_loss: 0.1271
# Epoch 3/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.1222 - val_loss: 0.1159
# Epoch 4/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.1139 - val_loss: 0.1100
# Epoch 5/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.1092 - val_loss: 0.1060
# Epoch 6/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.1060 - val_loss: 0.1038
# Epoch 7/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.1036 - val_loss: 0.1011
# Epoch 8/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.1016 - val_loss: 0.0995
# Epoch 9/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0999 - val_loss: 0.0978
# Epoch 10/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0984 - val_loss: 0.0963
# Epoch 11/50
# 469/469 [==============================] - 34s 74ms/step - loss: 0.0970 - val_loss: 0.0951
# Epoch 12/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0958 - val_loss: 0.0938
# Epoch 13/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0948 - val_loss: 0.0929
# Epoch 14/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0939 - val_loss: 0.0921
# Epoch 15/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0931 - val_loss: 0.0914
# Epoch 16/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0924 - val_loss: 0.0911
# Epoch 17/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0918 - val_loss: 0.0902
# Epoch 18/50
# 469/469 [==============================] - 35s 75ms/step - loss: 0.0912 - val_loss: 0.0902
# Epoch 19/50
# 469/469 [==============================] - 35s 74ms/step - loss: 0.0908 - val_loss: 0.0896
# Epoch 20/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0903 - val_loss: 0.0889
# Epoch 21/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0899 - val_loss: 0.0890
# Epoch 22/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0895 - val_loss: 0.0882
# Epoch 23/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0891 - val_loss: 0.0882
# Epoch 24/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0887 - val_loss: 0.0876
# Epoch 25/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0883 - val_loss: 0.0872
# Epoch 26/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0881 - val_loss: 0.0869
# Epoch 27/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0877 - val_loss: 0.0867
# Epoch 28/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0875 - val_loss: 0.0862
# Epoch 29/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0872 - val_loss: 0.0861
# Epoch 30/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0870 - val_loss: 0.0866
# Epoch 31/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0868 - val_loss: 0.0857
# Epoch 32/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0865 - val_loss: 0.0854
# Epoch 33/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0863 - val_loss: 0.0852
# Epoch 34/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0861 - val_loss: 0.0850
# Epoch 35/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0859 - val_loss: 0.0848
# Epoch 36/50
# 469/469 [==============================] - 34s 71ms/step - loss: 0.0857 - val_loss: 0.0848
# Epoch 37/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0856 - val_loss: 0.0844
# Epoch 38/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0854 - val_loss: 0.0844
# Epoch 39/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0853 - val_loss: 0.0844
# Epoch 40/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0852 - val_loss: 0.0840
# Epoch 41/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0850 - val_loss: 0.0839
# Epoch 42/50
# 469/469 [==============================] - 34s 74ms/step - loss: 0.0849 - val_loss: 0.0842
# Epoch 43/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0848 - val_loss: 0.0837
# Epoch 44/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0846 - val_loss: 0.0843
# Epoch 45/50
# 469/469 [==============================] - 34s 71ms/step - loss: 0.0846 - val_loss: 0.0835
# Epoch 46/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0845 - val_loss: 0.0834
# Epoch 47/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0844 - val_loss: 0.0833
# Epoch 48/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0843 - val_loss: 0.0833
# Epoch 49/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0842 - val_loss: 0.0832
# Epoch 50/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0841 - val_loss: 0.0830

# %%
# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=10)  # 테스트할 이미지를 랜덤하게 불러옵니다.
# 0~5999 사이에서 5개의 숫자 배열을 생성함

plt.figure(figsize=(7, 4))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):       # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(4, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(4, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28)) # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
